# %%
library(miloR)
library(igraph)
library(BiocParallel)
library(SingleCellExperiment)
library(Matrix)
library(dplyr)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal')
# Out:
# Loading required package: edgeR
#
# Loading required package: limma
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:miloR’:
#
#     graph
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SingleCellExperiment’
#
#
# The following object is masked from ‘package:edgeR’:
#
#     cpm
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
load('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave1_milo_prep.RData')
adata_no_knnx
# Out:
# class: SingleCellExperiment
# dim: 318 29899
# metadata(21): Interferon_group_colors WHO_temp_severity_colors ...
#   seurat_clusters_colors umap
# assays(2): X counts
# rownames(318): HES4 MEGF6 ... AC233755.2 AC233755.1
# rowData names(9): vst.mean vst.variance ... dispersions
#   dispersions_norm
# colnames(29899): UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1
#   UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 ...
#   UK-CIC10689787+UK-CIC10690075_TTCCCAGCATCGGTTA-1
#   UK-CIC10689787+UK-CIC10690075_TTGGAACGTTATGCGT-1
# colData names(67): orig.ident nCount_RNA ... time_from_positive_swab
#   time_from_infection
# reducedDimNames(6): X_harmony_rna X_pca_rna ... X_umapafterharmony_rna
#   X_umapbeforeharmony_rna
# altExpNames(0):

# %%
mylo <- Milo(adata_no_knnx)
milo_graph <- buildFromAdjacency(knn_adjacencyx, k=50, is.binary=TRUE)
miloR::graph(mylo) <- miloR::graph(milo_graph)

# %%
dim(reducedDims(mylo)[['X_scVI']])
# Out:
# [1] 29899    10

# %%
mylo <- buildGraph(mylo, k=50, d=10, reduced.dim="X_scVI", BPPARAM = MulticoreParam(progressbar = TRUE))
mylo <- makeNhoods(mylo, prop = 0.3, k=50, d=10, reduced_dim="X_scVI")
# Out:
#   |======================================================================| 100%
# Constructing kNN graph with k:50
#
# Checking valid object

# %%
mylo <- countCells_(mylo, meta.data = data.frame(colData(mylo)), samples="sample_id")
mylo <- calcNhoodDistance(mylo, d=10, reduced.dim = 'X_scVI', use.assay = 'counts')
mylo <- buildNhoodGraph(mylo)
saveRDS(mylo, 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave1_milo.RDS')
# Out:
# Checking meta.data validity
#
# Counting cells in neighbourhoods

# %%
# kernel died...
library(miloR)
library(igraph)
library(BiocParallel)
library(SingleCellExperiment)
library(Matrix)
library(dplyr)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal')
# Out:
# Loading required package: edgeR
#
# Loading required package: limma
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:miloR’:
#
#     graph
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SingleCellExperiment’
#
#
# The following object is masked from ‘package:edgeR’:
#
#     cpm
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mylo <- readRDS('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave1_milo.RDS')
metadata = data.frame(colData(mylo))

# %%
# metadata$case_control <- ordered(factor(metadata$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY')))
metadata$case_control <- factor(metadata$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY'))
metadata$WHO_temp_severity <- factor(metadata$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'))
metadata$WHO_temp_severity_group <- factor(metadata$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical'))
metadata$WHO_severity_group <- factor(metadata$WHO_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical')) # interpreted as peak severity
metadata$grouped_temp_severity <- ifelse(metadata$WHO_temp_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
metadata$grouped_severity <- ifelse(metadata$WHO_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
metadata$age_scaled <- scale(metadata$calc_age) # scale age
metadata$ethnicity = factor(metadata$ethnicity)
metadata$sex = factor(metadata$sex)
metadata$centre = factor(metadata$centre)

# %%
# remove 
metadata <- distinct(metadata[, c('sample_id', 'individual_id', 'case_control', 'WHO_temp_severity', 'WHO_temp_severity_group', 'WHO_severity_group', 'grouped_temp_severity', 'grouped_severity', 'sex', 'ethnicity', 'age_scaled', 'centre')], .keep_all = TRUE)
metadata
# Out:
#                                                  sample_id individual_id
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 C123_0505 C123
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 C103_2204 C103
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1 C214_2705 C214
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 C42_1504  C42
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 C40_0105  C40
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 C124_0105 C124
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1 C104_2204 C104
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 C123_2404 C123
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1 C106_2204 C106
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 C123_2904 C123
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 C126_0605 C126
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 C124_2404 C124
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1 C134_2904 C134
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 C127_0405 C127
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 C124_2704 C124
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 C126_2504 C126
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1 C142_3004 C142
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 C127_1105 C127
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 C128_0405 C128
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 C126_3004 C126
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 C132_0205 C132
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1 C152_0405 C152
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 C128_1105 C128
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 C127_2504 C127
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 C132_1105 C132
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 C20_1004  C20
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 C128_2504 C128
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 C161_1105 C161
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 C20_1404  C20
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 C132_2804 C132
# ⋮                                                ⋮         ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 C40_2204  C40
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 C36_2104  C36
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 C212_2705 C212
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 C113_0605 C113
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1 C234_2805 C234
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1 C93_2104  C93
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 C42_2704  C42
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 C113_2304 C113
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1 C237_2805 C237
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1 C93_2704  C93
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1 C60_1604  C60
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 C113_2904 C113
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 C238_2905 C238
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1 C60_2104  C60
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 C63_1704  C63
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 C240_2905 C240
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 C63_2404  C63
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1 C60_2504  C60
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1 C65_1704  C65
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 C63_2904  C63
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1 C65_2104  C65
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1 C73_2004  C73
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1 C246_2905 C246
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 C82_2004  C82
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 C251_2905 C251
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1 C65_2504  C65
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1 C73_2404  C73
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 C82_2504  C82
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1 C69_1804  C69
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1 C85_2004  C85
#                                                  case_control WHO_temp_severity
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 POSITIVE     moderate
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 NEGATIVE     NA
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1 NEGATIVE     NA
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 POSITIVE     moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 POSITIVE     critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 POSITIVE     mild
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1 NEGATIVE     NA
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 POSITIVE     severe
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1 NEGATIVE     NA
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 POSITIVE     severe
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 POSITIVE     mild
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 POSITIVE     moderate
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1 NEGATIVE     NA
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 POSITIVE     moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 POSITIVE     mild
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 POSITIVE     mild
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1 NEGATIVE     NA
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 POSITIVE     mild
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 POSITIVE     mild
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 POSITIVE     mild
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 POSITIVE     mild
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1 NEGATIVE     NA
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 POSITIVE     mild
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 POSITIVE     moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 POSITIVE     mild
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 POSITIVE     moderate
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 POSITIVE     mild
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 NEGATIVE     NA
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 POSITIVE     moderate
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 POSITIVE     moderate
# ⋮                                                ⋮            ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 POSITIVE     moderate
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 POSITIVE     mild
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 NEGATIVE     NA
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 POSITIVE     moderate
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1 NEGATIVE     NA
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1 POSITIVE     mild
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 POSITIVE     mild
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 POSITIVE     severe
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1 NEGATIVE     NA
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1 POSITIVE     moderate
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1 POSITIVE     moderate
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 POSITIVE     severe
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 NEGATIVE     NA
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1 POSITIVE     moderate
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 POSITIVE     moderate
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 NEGATIVE     NA
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 POSITIVE     mild
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1 POSITIVE     moderate
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1 POSITIVE     moderate
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 POSITIVE     mild
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1 POSITIVE     severe
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1 POSITIVE     moderate
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1 NEGATIVE     NA
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 POSITIVE     mild
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 NEGATIVE     NA
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1 POSITIVE     critical
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1 POSITIVE     mild
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 POSITIVE     mild
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1 NEGATIVE     NA
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1 NEGATIVE     NA
#                                                  WHO_temp_severity_group
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 mild_moderate
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 NA
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1 NA
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1 NA
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1 NA
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1 NA
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1 NA
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1 NA
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 NA
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate
# ⋮                                                ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 mild_moderate
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 mild_moderate
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 NA
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 mild_moderate
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1 NA
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1 mild_moderate
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 mild_moderate
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 severe_critical
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1 NA
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1 mild_moderate
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1 mild_moderate
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 severe_critical
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 NA
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1 mild_moderate
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 NA
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1 severe_critical
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1 NA
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 mild_moderate
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 NA
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1 severe_critical
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1 mild_moderate
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 mild_moderate
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1 NA
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1 NA
#                                                  WHO_severity_group
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 severe_critical
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 NA
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1 NA
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1 NA
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1 NA
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1 NA
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1 NA
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1 NA
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 severe_critical
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 NA
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 severe_critical
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate
# ⋮                                                ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 severe_critical
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 mild_moderate
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 NA
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 severe_critical
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1 NA
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1 mild_moderate
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 mild_moderate
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 severe_critical
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1 NA
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1 mild_moderate
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1 severe_critical
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 severe_critical
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 NA
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1 severe_critical
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 NA
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1 severe_critical
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1 severe_critical
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1 severe_critical
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1 severe_critical
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1 NA
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 mild_moderate
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 NA
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1 severe_critical
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1 severe_critical
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 mild_moderate
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1 NA
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1 NA
#                                                  grouped_temp_severity
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 mild_moderate
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 severe_critical
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1 severe_critical
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1 severe_critical
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1 severe_critical
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1 severe_critical
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 severe_critical
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate
# ⋮                                                ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 mild_moderate
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 mild_moderate
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 severe_critical
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 mild_moderate
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1 severe_critical
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1 mild_moderate
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 mild_moderate
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 severe_critical
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1 severe_critical
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1 mild_moderate
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1 mild_moderate
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 severe_critical
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 severe_critical
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1 mild_moderate
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 severe_critical
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1 mild_moderate
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1 severe_critical
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1 mild_moderate
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1 severe_critical
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 mild_moderate
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 severe_critical
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1 severe_critical
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1 mild_moderate
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 mild_moderate
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1 severe_critical
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1 severe_critical
#                                                  grouped_severity sex ethnicity
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 severe_critical  M   asian
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 severe_critical  M   asian
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1 severe_critical  F   white
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate    M   white
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical  M   black
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate    M   asian
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1 severe_critical  M   other
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical  M   asian
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1 severe_critical  M   white
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical  M   asian
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate    M   asian
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate    M   asian
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1 severe_critical  F   black
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate    F   other
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate    M   asian
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate    M   asian
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1 severe_critical  M   asian
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate    F   other
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate    M   asian
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate    M   asian
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate    F   asian
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1 severe_critical  M   other
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate    M   asian
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate    F   other
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate    F   asian
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 severe_critical  M   asian
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate    M   asian
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 severe_critical  M   other
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 severe_critical  M   asian
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate    F   asian
# ⋮                                                ⋮                ⋮   ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 severe_critical  M   black
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 mild_moderate    M   asian
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 severe_critical  M   white
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 severe_critical  F   white
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1 severe_critical  F   asian
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1 mild_moderate    M   white
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 mild_moderate    M   white
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 severe_critical  F   white
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1 severe_critical  M   asian
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1 mild_moderate    M   white
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1 severe_critical  M   white
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 severe_critical  F   white
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 severe_critical  F   black
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1 severe_critical  M   white
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 mild_moderate    M   black
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 severe_critical  M   asian
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 mild_moderate    M   black
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1 severe_critical  M   white
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1 severe_critical  M   white
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 mild_moderate    M   black
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1 severe_critical  M   white
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1 severe_critical  M   white
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1 severe_critical  M   white
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 mild_moderate    F   other
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 severe_critical  M   asian
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1 severe_critical  M   white
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1 severe_critical  M   white
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 mild_moderate    F   other
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1 severe_critical  M   asian
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1 severe_critical  F   white
#                                                  age_scaled  centre
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 -0.12081864 NCL
# UK-CIC10689738+UK-CIC10690026_AACCATGCAGTCACTA-1 -0.12081864 NCL
# UK-CIC10689740+UK-CIC10690028_AAACCTGAGACCCACC-1  0.04343538 NCL
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 -2.25612098 NCL
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 -0.85996176 NCL
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1  1.11108655 NCL
# UK-CIC10689742+UK-CIC10690030_AAAGTAGAGTGCTGCC-1  1.11108655 NCL
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 -0.12081864 NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAATGGACG-1  1.19321356 NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 -0.12081864 NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 -0.28507267 NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1  1.11108655 NCL
# UK-CIC10689746+UK-CIC10690034_AAACGGGTCCACGACG-1  0.53619746 NCL
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1  0.12556239 NCL
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1  1.11108655 NCL
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 -0.28507267 NCL
# UK-CIC10689748+UK-CIC10690036_AAACCTGAGTACATGA-1  0.53619746 NCL
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1  0.12556239 NCL
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1  0.37194343 NCL
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 -0.28507267 NCL
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1  0.78257850 NCL
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCGGCGCAT-1  0.70045148 NCL
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1  0.37194343 NCL
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1  0.12556239 NCL
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1  0.78257850 NCL
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 -0.44932670 NCL
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1  0.37194343 NCL
# UK-CIC10689752+UK-CIC10690040_ACTTTCATCTCAAGTG-1 -0.20294566 NCL
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 -0.44932670 NCL
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1  0.78257850 NCL
# ⋮                                                ⋮           ⋮
# UK-CIC10689768+UK-CIC10690056_AAACCTGGTGCACTTA-1 -0.8599618  NCL
# UK-CIC10689768+UK-CIC10690056_AACCATGAGCTAGTCT-1 -0.1208186  NCL
# UK-CIC10689768+UK-CIC10690056_AACTCCCGTAGCGTAG-1 -1.5169779  NCL
# UK-CIC10689770+UK-CIC10690058_AAACGGGCAATGGAGC-1 -0.5314537  NCL
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTCAACTT-1  0.5361975  NCL
# UK-CIC10689770+UK-CIC10690058_AAAGATGTCTTACCGC-1  1.6038486  NCL
# UK-CIC10689770+UK-CIC10690058_AAAGCAAGTTATGTGC-1 -2.2561210  NCL
# UK-CIC10689772+UK-CIC10690060_AAACGGGTCTGCCAGG-1 -0.5314537  NCL
# UK-CIC10689772+UK-CIC10690060_AAAGATGGTTCCGGCA-1  0.3719434  NCL
# UK-CIC10689772+UK-CIC10690060_AACACGTTCTGGCGAC-1  1.6038486  NCL
# UK-CIC10689772+UK-CIC10690060_AACTCTTAGGTGGGTT-1  1.0289595  NCL
# UK-CIC10689774+UK-CIC10690062_AAACGGGCACGCTTTC-1 -0.5314537  NCL
# UK-CIC10689774+UK-CIC10690062_AAACGGGTCGGCATCG-1 -2.3382480  NCL
# UK-CIC10689774+UK-CIC10690062_AAAGATGTCATACGGT-1  1.0289595  NCL
# UK-CIC10689774+UK-CIC10690062_AAATGCCTCAAGAAGT-1 -1.8454859  NCL
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTATGAAAC-1 -0.4493267  NCL
# UK-CIC10689776+UK-CIC10690064_AAACGGGGTCTCTCTG-1 -1.8454859  NCL
# UK-CIC10689776+UK-CIC10690064_AACGTTGCAATAGCGG-1  1.0289595  NCL
# UK-CIC10689776+UK-CIC10690064_AAGGTTCAGGTCGGAT-1  0.4540704  NCL
# UK-CIC10689778+UK-CIC10690066_AAACCTGCAATGACCT-1 -1.8454859  NCL
# UK-CIC10689778+UK-CIC10690066_AAGACCTTCAGATAAG-1  0.4540704  NCL
# UK-CIC10689778+UK-CIC10690066_AGCATACAGATACACA-1  1.6859756  NCL
# UK-CIC10689778+UK-CIC10690066_CAGAGAGGTAAGGGAA-1  0.2898164  NCL
# UK-CIC10689780+UK-CIC10690068_AAACCTGGTCAATACC-1 -0.6135807  NCL
# UK-CIC10689780+UK-CIC10690068_AAATGCCCAGGTCTCG-1 -2.1739940  NCL
# UK-CIC10689780+UK-CIC10690068_AACTCTTCAAACTGCT-1  0.4540704  NCL
# UK-CIC10689780+UK-CIC10690068_AACTTTCTCGCCAGCA-1  1.6859756  NCL
# UK-CIC10689784+UK-CIC10690072_AAACGGGGTCTTTCAT-1 -0.6135807  NCL
# UK-CIC10689784+UK-CIC10690072_AAAGATGCAAGCGATG-1  0.9468325  NCL
# UK-CIC10689786+UK-CIC10690074_ACGGGCTGTCGTTGTA-1  0.5361975  NCL

# %%
library(lmerTest)
library(pbmcapply)
# Out:
# Loading required package: lme4
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
res <- as.list(1:nrow(nhoodCounts(mylo)))
res <- pbmclapply(res, function(x) glmer.nb(nhoodCounts(mylo)[x,] ~ case_control + sex + ethnicity + age_scaled + (1|individual_id), offset = log(colSums(nhoodCounts(mylo))), data = metadata, control=glmerControl(check.conv.singular = .makeCC(action = "ignore",  tol = 1e-2), optimizer="bobyqa", tol=1e-02)), mc.cores = parallel::detectCores())
res_summary <- pbmclapply(res, summary)
save(res_summary, res, metadata, file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave1_milo_results.RData')

# %%
load(file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave1_milo_results.RData')

# %%
# example coefficients for 1 neighborhood
res_summary[[1]]$coefficients
# Out:
#                      Estimate    Std. Error z value      Pr(>|z|)
# (Intercept)          -9.11511760 0.5210755  -17.49289097 1.623106e-68
# case_controlPOSITIVE  0.10819049 0.4108965    0.26330353 7.923166e-01
# sexM                  0.11358220 0.4216305    0.26938802 7.876311e-01
# ethnicityblack        0.23846647 0.6419603    0.37146611 7.102904e-01
# ethnicityother        0.01586764 0.6496021    0.02442670 9.805122e-01
# ethnicitywhite       -0.50093936 0.4836274   -1.03579611 3.002973e-01
# age_scaled            0.01847177 0.2220251    0.08319677 9.336951e-01

# %%
singulars <- lapply(res, function(x) as.numeric(isSingular(x)))
conv <- lapply(res, function(x) length(slot(x, "optinfo")$conv$lme4$messages))

# %%
pvalue <- pbmclapply(res_summary, function(x) x$coefficients[2,4])
beta <- pbmclapply(res_summary, function(x) x$coefficients[2,1])

# %%
da.res = data.frame(Nhood = as.numeric(1:nrow(nhoodCounts(mylo))), beta = do.call(c, beta), PValue = do.call(c, pvalue))

# %%
da.res$Singular <- singulars
da.res$Conv <- conv

# %%
da.res$SpatialFDR <- graphSpatialFDR(x.nhoods=nhoods(mylo), graph=miloR::graph(mylo),
    weighting='k-distance', pvalues=da.res$PValue,
    indices=nhoodIndex(mylo), distances=nhoodDistances(mylo),
    reduced.dimensions=reducedDim(mylo, 'X_scVI'), k = 50)
da.res$Diff <- sign(da.res$beta)
da.res$Diff[da.res$SpatialFDR >= 0.1 | da.res$Singular > 0 | da.res$Conv > 0] <- 0
saveRDS(da.res, file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave1_milo_results_DA.RDS')

# %%
table(da.res$Diff)
# Out:
#   -1    0    1
#  573 6469  236

# %%
library(ggbeeswarm)
library(ggplot2)
new_DA_beeswarm <- function (da.res1, da.res2 = NULL, max = 5, color.by = 'SpatialFDR', group.by = NULL, split.by =NULL, alpha = 0.1, subset.nhoods = NULL, size = 2, filter = c('Mixed', 'doublets')) {
    if (!is.null(da.res2) && !is.null(split.by)){
        da.res1$split = split.by[1]
        da.res2$split = split.by[2]
        da.res <- rbind(da.res1, da.res2)
    } else {
        da.res <- da.res1
    }

    da.res$beta[da.res$beta > max] <- max
    da.res$beta[da.res$beta < -max] <- -max
    da.res <- da.res %>% filter(!get(group.by) %in% filter)
    if (!is.null(group.by)) {
        if (!group.by %in% colnames(da.res)) {
            stop(paste0(group.by, " is not a column in da.res. Have you forgot to run annotateNhoods(x, da.res, ", 
                group.by, ")?"))
        }
        if (is.numeric(da.res[, group.by])) {
            stop(paste0(group.by, " is a numeric variable. Please bin to use for grouping."))
        }
        da.res <- mutate(da.res, group_by = da.res[, group.by])
    }else {
        da.res <- mutate(da.res, group_by = "g1")
    }    
    if (!is.factor(da.res[, "group_by"])) {
        message(paste0("Converting group.by to factor..."))
        da.res <- mutate(da.res, factor(group_by, levels = unique(group_by)))
    }
    if (!is.null(subset.nhoods)) {
        da.res <- da.res[subset.nhoods, ]
    }
    
    da.res <- da.res %>% mutate(is_signif = ifelse((get(color.by) < alpha & get('Singular') < 1 & get('Conv') < 1), 
        1, 0)) %>% mutate(beta_color = ifelse(is_signif == 1, 
        beta, NA)) %>% arrange(group_by) %>% mutate(Nhood = factor(Nhood, 
        levels = unique(Nhood)))
    if (!is.null(split.by)){
        p <- ggplot(da.res, aes(group_by, beta, color = beta_color)) + 
            scale_color_gradient2(midpoint = 0, low = "#0571b0", mid = '#f7f7f7', high = "#ca0020", limits=c(-max/3, max/3), oob=scales::squish) +
            guides(color = "none") + 
            xlab(group.by) + 
            ylab("beta") + 
            geom_quasirandom(alpha = 1, size = size) +
            coord_flip() + 
            theme_bw() + 
            theme(axis.title.y = element_blank(),
                  axis.title.x = element_text(size=20, color = '#000000'),
                  axis.text = element_text(size=20, color = '#000000'),
                  axis.ticks = element_line(color = '#000000'),
                  panel.border = element_rect(colour = "#000000")
                ) + 
            facet_wrap(split~.) +
            theme(strip.background = element_blank(), strip.text.x = element_text(angle = 0, size = 20, color = '#000000'))
    } else {
        p <- ggplot(da.res, aes(group_by, beta, color = beta_color)) + 
        scale_color_gradient2(midpoint = 0, low = "#0571b0", mid = '#f7f7f7', high = "#ca0020", limits=c(-max/3, max/3), oob=scales::squish) +
        guides(color = "none") + 
        xlab(group.by) + 
        ylab("beta") + 
        geom_quasirandom(alpha = 1, size = size) +
        coord_flip() + 
        theme_bw() + 
        theme(axis.title.y = element_blank(),
              axis.title.x = element_text(size=20, color = '#000000'),
              axis.text = element_text(size=20, color = '#000000'),
              axis.ticks = element_line(color = '#000000'),
              panel.border = element_rect(colour = "#000000")
            ) + 
        theme(strip.background = element_blank(), strip.text.x = element_text(angle = 0, size = 20, color = '#000000'))
    }
    
    p$data <- p$data[order(p$data$beta_color, na.last = FALSE), ]
    return(p)
}

# %%
# options(repr.plot.width=20, repr.plot.height=10)
da.res <- annotateNhoods(mylo, da.res, coldata_col = "celltype_B_corrected")
da.res$celltype_B_corrected <- ifelse(da.res$celltype_B_corrected_fraction < 0.7, "Mixed", da.res$celltype_B_corrected)
p <- new_DA_beeswarm(da.res, color.by = 'SpatialFDR', group.by = "celltype_B_corrected", size = 2, alpha = .05)
p
# Out:
# Converting group.by to factor...
# plot without title

# %%
# options(repr.plot.width=20, repr.plot.height=10)
da.res <- annotateNhoods(mylo, da.res, coldata_col = "celltype_B_corrected_IFN")
da.res$celltype_B_corrected_IFN <- ifelse(da.res$celltype_B_corrected_IFN_fraction < 0.7, "Mixed", da.res$celltype_B_corrected_IFN)
p <- new_DA_beeswarm(da.res, color.by = 'SpatialFDR', group.by = "celltype_B_corrected_IFN", size = 2, alpha = .05)
p
# Out:
# Converting group.by to factor...
# plot without title
