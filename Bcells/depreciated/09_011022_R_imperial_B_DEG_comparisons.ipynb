# %%
library(glmmSeq)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal/')
# Out:
# Registered S3 methods overwritten by 'lme4':
#   method                          from
#   cooks.distance.influence.merMod car
#   influence.merMod                car
#   dfbeta.influence.merMod         car
#   dfbetas.influence.merMod        car

# %%
load('h5ad/glmmSeq_B_ASC_all.RData')
ls()
# Out:
# [1] "results1" "results2" "results3" "results4"

# %%
results1 <- glmmQvals(results1, pi0=1)
# Out:
# q_case_control
# --------------
# Not Significant     Significant
#            5291            4679
#
# q_sex
# -----
# Not Significant     Significant
#            8998             972
#
# q_ethnicity
# -----------
# Not Significant     Significant
#            8865            1105
#
# q_calc_age
# ----------
# Not Significant     Significant
#            9534             436

# %%
results2 <- glmmQvals(results2, pi0=1)
# Out:
# q_case_control
# --------------
# Not Significant     Significant
#            4481            5489
#
# q_sex
# -----
# Not Significant     Significant
#            8785            1185
#
# q_ethnicity
# -----------
# Not Significant     Significant
#            8749            1221
#
# q_calc_age
# ----------
# Not Significant     Significant
#            9380             590
#
# q_days_to_admission
# -------------------
# Not Significant     Significant
#            8875            1095

# %%
results3 <- glmmQvals(results3, pi0=1)
# Out:
# q_WHO_severity
# --------------
# Not Significant     Significant
#            1130            8840
#
# q_sex
# -----
# Not Significant     Significant
#            8862            1108
#
# q_ethnicity
# -----------
# Not Significant     Significant
#            8756            1214
#
# q_calc_age
# ----------
# Not Significant     Significant
#            9536             434

# %%
results4 <- glmmQvals(results4, pi0=1)
# Out:
# q_WHO_severity
# --------------
# Not Significant     Significant
#             636            9334
#
# q_sex
# -----
# Not Significant     Significant
#            8827            1143
#
# q_ethnicity
# -----------
# Not Significant     Significant
#            8733            1237
#
# q_calc_age
# ----------
# Not Significant     Significant
#            9476             494
#
# q_days_to_admission
# -------------------
# Not Significant     Significant
#            8396            1574

# %%
degTable <- function(results, contrast, group){    
    modelData <- results@modelData
    outLabels <- apply(modelData, 1, function(x) paste(x, collapse="_"))
    modelData$y <- paste0('y_', outLabels)
    cols1 = grep(group, modelData$y, value = TRUE)
    cols2 = grep(group, modelData$y, value = TRUE, invert = TRUE)
    LFC <- log2(rowMeans(results@predict[, cols1])+1) - log2(rowMeans(results@predict[, cols2])+1)
    tmp <- data.frame(results@stats[,c(paste0(contrast, group), paste0('P_',contrast), paste0('q_',contrast))])
    colnames(tmp) <- c('fixed-effects estimates', 'pval', 'qval')
    tmp$LFC <- LFC
    tmp <- tmp[order(-tmp$`fixed-effects estimates`, tmp$qval), ]
    return(tmp)
}

# %%
res1 <- degTable(results1, 'case_control', 'POSITIVE')
head(res1)
# Out:
#         fixed-effects estimates pval         qval         LFC
# TMED5   2.157676                1.876799e-11 1.811393e-10 1.645022
# SRSF9   2.123304                1.170271e-16 1.243881e-15 1.519496
# NDUFA12 2.098023                1.295392e-12 1.301922e-11 1.818110
# HM13    2.088680                3.858901e-11 3.688710e-10 1.767537
# SSR3    2.073148                7.761194e-16 8.170972e-15 1.695220
# ATP6V0B 2.037531                3.762476e-12 3.714048e-11 1.681106

# %%
res2 <- degTable(results1, 'case_control', 'RECOVERY')
head(res2)
# Out:
#         fixed-effects estimates pval         qval         LFC
# ADIPOR1 1.696190                6.679787e-05 3.277435e-04  0.75859098
# SRSF9   1.565479                1.170271e-16 1.243881e-15  0.03196005
# ABHD5   1.560959                2.478209e-02 5.230260e-02  1.05453950
# SRPRA   1.537723                1.135702e-09 1.010978e-08  0.16781532
# CES1    1.526080                4.142168e-02 7.869200e-02  1.77024547
# TMED5   1.490394                1.876799e-11 1.811393e-10 -0.11873613

# %%
library(dplyr)
makeGeneList <- function(gl){
    y <- grepl('^RPS|^RPL|^MT-', row.names(gl))
    gl <- gl[!y, ]
    rank <- -log10(gl$pval) * sign(gl$LFC)
    rank[which(rank == Inf)] <- 300
    rank[which(rank == -Inf)] <- 300
    names(rank) <- row.names(gl)
    rank <- rev(sort(rank))
    gl <- rank
    return(gl)
}

# %%
gl1 <- makeGeneList(res1)
gl2 <- makeGeneList(res2)

# %%
library(fgsea)
library(msigdbr)

# %%
h <- data.frame(msigdbr::msigdbr(category = "H", species = 'Homo sapiens'))
h <- split(h, h$gs_name)
h <- lapply(h, function(x) x %>% dplyr::select(gene_symbol) %>% unlist %>% as.character)

# %%
res1gsea <- fgsea(pathways = h, stats = gl1, minSize = 0, maxSize =1000)
# Out:
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (8.6% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”

# %%
res2gsea <- fgsea(pathways = h, stats = gl2, minSize = 0, maxSize =1000)
# Out:
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (8.6% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”

# %%
res1gsea
# Out:
#    pathway                                    pval         padj
# 1  HALLMARK_ADIPOGENESIS                      9.130869e-01 1.000000e+00
# 2  HALLMARK_ALLOGRAFT_REJECTION               4.155844e-01 7.165249e-01
# 3  HALLMARK_ANDROGEN_RESPONSE                 8.531469e-01 1.000000e+00
# 4  HALLMARK_ANGIOGENESIS                      6.524184e-01 9.211915e-01
# 5  HALLMARK_APICAL_JUNCTION                   4.695305e-01 7.590133e-01
# 6  HALLMARK_APICAL_SURFACE                    1.239001e-03 3.097503e-02
# 7  HALLMARK_APOPTOSIS                         3.606394e-01 6.493506e-01
# 8  HALLMARK_BILE_ACID_METABOLISM              3.626374e-01 6.493506e-01
# 9  HALLMARK_CHOLESTEROL_HOMEOSTASIS           5.694306e-02 2.372627e-01
# 10 HALLMARK_COAGULATION                       2.977023e-01 6.493506e-01
# 11 HALLMARK_COMPLEMENT                        9.790210e-02 3.496503e-01
# 12 HALLMARK_DNA_REPAIR                        1.000000e+00 1.000000e+00
# 13 HALLMARK_E2F_TARGETS                       2.941356e-03 4.902260e-02
# 14 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 37 CTSF   , NINJ1  , RALGDS , CDKN1A , TRIB3  , SP1    , RAP2B  , AEN    , CCND3  , PPM1D  , RGS16  , RAD51C , KIF13B , HMOX1  , SEC61A1, HINT1  , RACK1
# 38 SRP14 , SEC11A, SPCS1 , SRP9  , SRPRB
# 39 ABCD1 , TOP2A , PEX11B, PRDX5 , SOD1  , FDPS
# 40 CDKN1A  , TRIB3   , NOD1    , CXCR4   , VAV3    , AKT1    , PIKFYVE , STAT2   , TNFRSF1A, PRKCB   , CALR    , GRB2    , PPP1CA  , YWHAB
# 41 SCRN1  , VAMP7  , GOSR2  , AP2B1  , YIPF6  , GLA    , GNAS   , COPE   , SOD1   , TMED10 , LMAN1  , AP2M1  , ERGIC3 , SEC31A , RAB2A  , COPB2  , GOLGA4 , TMED2  , SCAMP3 , AP3B1  , ARFGAP3, AP2S1  , RER1   , NAPA   , SEC24D , SEC22B , ARCN1
# 42 SCAF4  , GLRX2  , NDUFB4 , SOD1   , PRDX6  , LSP1   , SELENOS, PRDX1
# 43 STAM2, TLE4 , LPIN1, IP6K1, PSMG1, PHKG2, MTOR
# 44 SMAD3 , PPP1CA
# 45 DUSP4 , NINJ1 , CDKN1A, RELB  , GCH1  , PDLIM5, AREG  , NFAT5 , ICAM1 , RHOB  , NFKB1 , DUSP5 , G0S2  , SMAD3 , ATP2B1
# 46 DNAJA4, GEMIN4, EXOSC2, GOSR2 , EDC4  , EXOSC9, NOP56 , EXOSC5, TATDN2, KHSRP , DDX10 , MTREX , CXXC1 , SERP1
# 47 NR1D2 , PDLIM5, CITED2, NFKB1 , COL1A2, DYRK1A, SMAD3 , PIAS3 , MET   , ATP2C1, ATP2B1, PRDM2 , MAPK14, MRPS31
# 48 GRINA  , GCH1   , ICAM1  , RHOB   , PPIF   , CCND3  , PRKACA , GGH    , RAB27A , NUP58  , HMOX1  , MGAT1  , TMBIM6 , RPN1   , ATP6V1F
# 49 ADAM17, FRAT1 , HDAC2
# 50 MT2A    , NINJ1   , GCH1    , CROT    , PDLIM5  , HACL1   , POR     , ESR1    , HPRT1   , ATP2A2  , PTS     , MTHFD1  , UGDH    , CBR1    , TNFRSF1A, HMOX1   , SSR3

# %%
plotGSEA_Hallmark <- function(gsea, cols = NULL, xlim = NULL, newlabels = NULL, keep_significant_only = TRUE, jitter = FALSE) {
    require(ggplot2)
    gsea$NES[which(is.na(gsea$NES))] <- 0
    gsea$pval[which(is.na(gsea$pval))] <- 1
    gsea$padj[which(is.na(gsea$padj))] <- 1
    gsea$ranking[which(is.na(gsea$ranking))] <- 0
    gsea <- gsea[order(gsea$ranking),]
    
    if (keep_significant_only){
        gseax <- split(gsea, gsea$pathway)
        for (i in 1:length(gseax)){
            if (all(gseax[[i]]$pval >= 0.05)|all(gseax[[i]]$padj >=0.25)){
                gseax[[i]] <- NA        
            }
        }
        gseax <- gseax[!is.na(gseax)]
        gsea <- do.call(rbind, gseax)        
    }
    if (!is.null(gsea)){
        gsea <- gsea[order(gsea$ranking), ]
        gsea$pathway <- gsub("HALLMARK_|", "", gsea$pathway)

        if (!is.null(xlim)){
            x_lim_min = -xlim
            x_lim_max = xlim
        } else {
            x_lim_min <- abs(ceiling(min(-log10(gsea$padj))))
            x_lim_max <- abs(ceiling(max(-log10(gsea$padj))))
        }
        
        if(x_lim_min > x_lim_max){
            xval1 <- x_lim_min * -1
            xval2 <- x_lim_min
        } else {
            xval1 <- x_lim_max * -1
            xval2 <- x_lim_max
        }

        if(!is.null(cols)){
            gg_color_hue <- function(n) {
                hues = seq(15, 375, length = n + 1)
                hcl(h = hues, l = 65, c = 100)[1:n]
            }
            cols. = gg_color_hue(dplyr::n_distinct(gsea$group, na.rm = TRUE))
        } else {
            cols. = cols
        }    
    
        g <- ggplot(gsea, aes(x = -log10(padj)*sign(NES), y = reorder(pathway, ranking), col = -log10(padj)*sign(NES), size = abs(NES)))
        if (jitter){
            g <- g + geom_point(position = 'jitter')
        }else{
            g <- g + geom_point()
        }
        g <- g + theme_bw() +
            labs(x = expression(paste("Signed", " -log" ["10"], "adjusted pval")), y = "Hallmarks") +
            geom_vline(xintercept = 0) +
            geom_vline(xintercept = -log10(0.25)) +
            geom_vline(xintercept = -log10(0.25)*-1) +
            scale_x_continuous(limits = c(xval1, xval2), oob = scales::squish) +
            scale_size_area(oob = scales::squish, max_size = 3, limits = c(0,2)) +
            theme(panel.grid.major = element_blank(), 
                panel.grid.minor = element_blank(), 
                panel.background = element_blank(), 
                axis.line = element_blank(), 
                axis.ticks = element_blank(),
                axis.text = element_text(color = 'black'),
                axis.title = element_text(color = 'black'))
        
        return(g)
    }
}

# %%
plotGSEA_Hallmark(res1gsea)
# Out:
# plot without title

# %%
res1gsea[res1gsea$pathway == '']
# Out:
#    pathway                                    pval         padj
# 1  HALLMARK_ADIPOGENESIS                      9.130869e-01 1.000000e+00
# 2  HALLMARK_ALLOGRAFT_REJECTION               4.155844e-01 7.165249e-01
# 3  HALLMARK_ANDROGEN_RESPONSE                 8.531469e-01 1.000000e+00
# 4  HALLMARK_ANGIOGENESIS                      6.524184e-01 9.211915e-01
# 5  HALLMARK_APICAL_JUNCTION                   4.695305e-01 7.590133e-01
# 6  HALLMARK_APICAL_SURFACE                    1.239001e-03 3.097503e-02
# 7  HALLMARK_APOPTOSIS                         3.606394e-01 6.493506e-01
# 8  HALLMARK_BILE_ACID_METABOLISM              3.626374e-01 6.493506e-01
# 9  HALLMARK_CHOLESTEROL_HOMEOSTASIS           5.694306e-02 2.372627e-01
# 10 HALLMARK_COAGULATION                       2.977023e-01 6.493506e-01
# 11 HALLMARK_COMPLEMENT                        9.790210e-02 3.496503e-01
# 12 HALLMARK_DNA_REPAIR                        1.000000e+00 1.000000e+00
# 13 HALLMARK_E2F_TARGETS                       2.941356e-03 4.902260e-02
# 14 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSIT
# 2  IL2RB , IL27RA, GZMA  , ICAM1 , IRF7  , AKT1  , CCND3 , MTIF2 , ABCE1 , NME1  , CD8A  , PRKCB , B2M   , SRGN
# 3  PDLIM5 , AKT1   , CCND3  , APPBP2 , UAP1   , UBE2J1 , B2M    , SPCS3  , TMEM50A, LMAN1
# 4  LRPAP1, VEGFA , APP   , CCND2
# 5  ICAM1 , STX4  , MAPK14, PBX2  , ACTN4 , TUBG1 , ARPC2
# 6  IL2RB, FLOT2, IL2RG
# 7  CDKN1A, PDCD4 , GCH1  , ANXA1 , HMGB2 , SC5D  , RHOB  , CREBBP, TOP2A , CASP7 , NEDD9 , PLCB2 , HMOX1 , BCAP31, SOD1
# 8  PECR   , CROT   , ABCD1  , OPTN   , PEX12  , HACL1  , SLC27A5, PRDX5  , SOD1
# 9  TRIB3, SC5D , PCYT2, FDPS
# 10 LTA4H, ANXA1, MSRB2, CSRP1, ARF4 , ISCU
# 11 LTA4H , MSRB1 , GZMA  , IRF7  , RCE1  , DUSP5 , CASP7 , STX4  , DOCK10, GMFB  , CSRP1 , PRCP  , GRB2
# 12 HPRT1  , GTF2H3 , NFX1   , NME1   , EDF1   , DAD1   , GUK1   , BCAP31 , SEC61A1, APRT   , MRPL40 , TAF10
# 13 CDKN1A, HMGB2 , CENPM , DCTPP1, POLD2 , TOP2A , HUS1  , CDCA3 , PDS5B , USP1  , SPC25 , KIF4A , SLBP  , PPM1D , UBR7  , ORC2  , PPP1R8, SMC3  , NOP56 , NUP107, SMC1A , RAD51C, PHF5A , HMGB3 , NME1  , TUBG1 , RFC1
# 14 AREG  , RHOB  , COL1A2, P3H1  , PPIB
# 15 CHPT1  , AREG   , PPIF   , AFF1   , MED24  , SLC37A1, GLA    , GAB2
# 16 PDCD4 , CHPT1 , AREG  , PPIF  , TOP2A , RABEP1, BATF  , AFF1  , HPRT1 , MOCS2 , GLA   , ETFB  , UGDH  , COX6C
# 17 G0S2    , PTS     , UGDH    , RAP1GDS1, CBR1    , OSTC    , PSME1   , ERP29   , ACADVL  , MIF     , PRDX6   , ECHS1   , MDH2    , HSD17B10
# 18 MT2A  , UBE2C , CHAF1A, KIF11 , PML   , TOP2A , CDC7  , HUS1  , NUMA1 , SMAD3 , PDS5B , TROAP , CUL4A , KIF4A , TPX2  , PURA  , MAPK14, DTYMK , POLQ  , TLE3  , SMC1A , HMGB3 , NUP50 , UCK2  , EWSR1
# 19 CXCR4 , CITED2, GNE   , BPNT1 , MET   , RRAGD , GALK2 , MED24 , SOD1
# 20 PML , TLE3, CDK6
# 21 ACP5   , OPTN   , FOXJ2  , MOSPD1 , CAST   , MKRN1  , DCAF10 , RNF19A , TNRC6B , CCND3  , NFE2L1 , SEC14L1, TENT5C , TCEA1
# 22 MT2A  , CDKN1A, CXCR4 , CITED2, HK1   , GBE1  , RRAGD , HEXA  , HMOX1 , PRDX5
5F1A , ECHS1   , UQCRQ   , MDH2    , UQCR10  , HSD17B10, NDUFS7  , UQCRB   , ATP6V1G1, ISCU    , TIMM13  , SLC25A3 , ATP5F1B , PHB2    , UQCR11  , PDHA1   , NDUFC1  , IDH2    , TIMM8B  , MDH1    , ATP5F1E , ATP6V0E1, ATP5MC3 , MRPS15  , TOMM22  , NDUFAB1 , ACO2    , ATP6V0C , IDH3G   , UQCRC1  , COX7A2L , OXA1L   , COX8A   , ATP5MC1 , FDX1    , MRPL34  , DECR1   , SDHA    , NDUFS2  , LDHB    , ACADM   , CYCS    , SLC25A6 , ATP5PB  , NDUFB2  , SDHB    , SURF1   , NDUFB1  , COX17
# 37 CTSF   , NINJ1  , RALGDS , CDKN1A , TRIB3  , SP1    , RAP2B  , AEN    , CCND3  , PPM1D  , RGS16  , RAD51C , KIF13B , HMOX1  , SEC61A1, HINT1  , RACK1
# 38 SRP14 , SEC11A, SPCS1 , SRP9  , SRPRB
# 39 ABCD1 , TOP2A , PEX11B, PRDX5 , SOD1  , FDPS
# 40 CDKN1A  , TRIB3   , NOD1    , CXCR4   , VAV3    , AKT1    , PIKFYVE , STAT2   , TNFRSF1A, PRKCB   , CALR    , GRB2    , PPP1CA  , YWHAB
# 41 SCRN1  , VAMP7  , GOSR2  , AP2B1  , YIPF6  , GLA    , GNAS   , COPE   , SOD1   , TMED10 , LMAN1  , AP2M1  , ERGIC3 , SEC31A , RAB2A  , COPB2  , GOLGA4 , TMED2  , SCAMP3 , AP3B1  , ARFGAP3, AP2S1  , RER1   , NAPA   , SEC24D , SEC22B , ARCN1
# 42 SCAF4  , GLRX2  , NDUFB4 , SOD1   , PRDX6  , LSP1   , SELENOS, PRDX1
# 43 STAM2, TLE4 , LPIN1, IP6K1, PSMG1, PHKG2, MTOR
# 44 SMAD3 , PPP1CA
# 45 DUSP4 , NINJ1 , CDKN1A, RELB  , GCH1  , PDLIM5, AREG  , NFAT5 , ICAM1 , RHOB  , NFKB1 , DUSP5 , G0S2  , SMAD3 , ATP2B1
# 46 DNAJA4, GEMIN4, EXOSC2, GOSR2 , EDC4  , EXOSC9, NOP56 , EXOSC5, TATDN2, KHSRP , DDX10 , MTREX , CXXC1 , SERP1
# 47 NR1D2 , PDLIM5, CITED2, NFKB1 , COL1A2, DYRK1A, SMAD3 , PIAS3 , MET   , ATP2C1, ATP2B1, PRDM2 , MAPK14, MRPS31
# 48 GRINA  , GCH1   , ICAM1  , RHOB   , PPIF   , CCND3  , PRKACA , GGH    , RAB27A , NUP58  , HMOX1  , MGAT1  , TMBIM6 , RPN1   , ATP6V1F
# 49 ADAM17, FRAT1 , HDAC2
# 50 MT2A    , NINJ1   , GCH1    , CROT    , PDLIM5  , HACL1   , POR     , ESR1    , HPRT1   , ATP2A2  , PTS     , MTHFD1  , UGDH    , CBR1    , TNFRSF1A, HMOX1   , SSR3

# %%
plotGSEA_Hallmark(res2gsea)
# Out:
# plot without title
