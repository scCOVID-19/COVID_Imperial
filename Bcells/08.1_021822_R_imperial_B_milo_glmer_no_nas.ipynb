# %%
library(miloR)
library(igraph)
library(BiocParallel)
library(SingleCellExperiment)
library(Matrix)
library(dplyr)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal')
# Out:
# Loading required package: edgeR
#
# Loading required package: limma
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:miloR’:
#
#     graph
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SingleCellExperiment’
#
#
# The following object is masked from ‘package:edgeR’:
#
#     cpm
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
load('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_no_nas_milo_prep.RData')
adata_no_knnx
# Out:
# class: SingleCellExperiment
# dim: 318 45942
# metadata(21): Interferon_group_colors WHO_temp_severity_colors ...
#   seurat_clusters_colors umap
# assays(2): X counts
# rownames(318): HES4 MEGF6 ... AC233755.2 AC233755.1
# rowData names(9): vst.mean vst.variance ... dispersions
#   dispersions_norm
# colnames(45942): UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1
#   UK-CIC10689738+UK-CIC10690026_AAGGTTCGTGCGCTTG-1 ...
#   UK-CIC10690384+UK-CIC10690576_TTTGGTTGTACGAAAT-1
#   UK-CIC10690384+UK-CIC10690576_TTTGGTTGTTGTCTTT-1
# colData names(67): orig.ident nCount_RNA ... time_from_positive_swab
#   time_from_infection
# reducedDimNames(6): X_harmony_rna X_pca_rna ... X_umapafterharmony_rna
#   X_umapbeforeharmony_rna
# altExpNames(0):

# %%
unique(adata_no_knnx$case_control)
# Out:
# [1] POSITIVE
# Levels: POSITIVE

# %%
mylo <- Milo(adata_no_knnx)
milo_graph <- buildFromAdjacency(knn_adjacencyx, k=50, is.binary=TRUE)
miloR::graph(mylo) <- miloR::graph(milo_graph)

# %%
dim(reducedDims(mylo)[['X_scVI']])
# Out:
# [1] 45942    10

# %%
mylo <- buildGraph(mylo, k=50, d=10, reduced.dim="X_scVI", BPPARAM = MulticoreParam(progressbar = TRUE))
mylo <- makeNhoods(mylo, prop = 0.3, k=50, d=10, reduced_dim="X_scVI")
# Out:
#   |======================================================================| 100%
# Constructing kNN graph with k:50
#
# Checking valid object

# %%
mylo <- countCells_(mylo, meta.data = data.frame(colData(mylo)), samples="sample_id")
mylo <- calcNhoodDistance(mylo, d=10, reduced.dim = 'X_scVI', use.assay = 'counts')
mylo <- buildNhoodGraph(mylo)
saveRDS(mylo, 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_no_nas_milo.RDS')
# Out:
# Checking meta.data validity
#
# Counting cells in neighbourhoods

# %%
# kernel died...
library(miloR)
library(igraph)
library(BiocParallel)
library(SingleCellExperiment)
library(Matrix)
library(dplyr)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal')
# Out:
# Loading required package: edgeR
#
# Loading required package: limma
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:miloR’:
#
#     graph
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SingleCellExperiment’
#
#
# The following object is masked from ‘package:edgeR’:
#
#     cpm
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mylo <- readRDS('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_no_nas_milo.RDS')
metadata = data.frame(colData(mylo))

# %%
# metadata$case_control <- ordered(factor(metadata$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY')))
metadata$case_control <- factor(metadata$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY'))
metadata$WHO_temp_severity <- factor(metadata$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'))
metadata$WHO_temp_severity_group <- factor(metadata$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical'))
metadata$WHO_severity_group <- factor(metadata$WHO_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical')) # interpreted as peak severity
metadata$grouped_temp_severity <- ifelse(metadata$WHO_temp_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
metadata$grouped_severity <- ifelse(metadata$WHO_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
metadata$age_scaled <- scale(metadata$calc_age) # scale age
metadata$ethnicity = factor(metadata$ethnicity)
metadata$sex = factor(metadata$sex)
metadata$centre = factor(metadata$centre)

# %%
# remove 
metadata <- distinct(metadata[, c('sample_id', 'individual_id', 'case_control', 'WHO_temp_severity', 'WHO_temp_severity_group', 'WHO_severity_group', 'grouped_temp_severity', 'grouped_severity', 'sex', 'ethnicity', 'age_scaled', 'centre')], .keep_all = TRUE)
metadata
# Out:
#                                                  sample_id   individual_id
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 C123_0505   C123
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 C42_1504    C42
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 C40_0105    C40
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 C124_0105   C124
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 C123_2404   C123
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 C123_2904   C123
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 C126_0605   C126
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 C124_2404   C124
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 C127_0405   C127
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 C124_2704   C124
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 C126_2504   C126
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 C127_1105   C127
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 C128_0405   C128
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 C126_3004   C126
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 C132_0205   C132
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 C128_1105   C128
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 C127_2504   C127
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 C132_1105   C132
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 C20_1004    C20
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 C128_2504   C128
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 C20_1404    C20
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 C132_2804   C132
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1 C21_1004    C21
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1 C20_1604    C20
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1 C21_1704    C21
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1 C23_1004    C23
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1 C21_2504    C21
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 C31_1304    C31
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1 C23_1504    C23
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1 C23_2204    C23
# ⋮                                                ⋮           ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1 C169_300121 C169
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 C187_140121 C187
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 C170_300121 C170
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1 C33_190121  C33
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 C190_030221 C190
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1 C187_190121 C187
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1 C101_110121 C101
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1 C58_270121  C58
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1 C170_280121 C170
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1 C33_260121  C33
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 C190_080221 C190
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 C187_230121 C187
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1 C108_180121 C108
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1 C58_010221  C58
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1 C33_160121  C33
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 C190_050221 C190
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1 C58_250121  C58
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1 C101_200121 C101
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 C138_280121 C138
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1 C58_040221  C58
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1 C141_260121 C141
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 C140_060221 C140
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 C137_190121 C137
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 C138_260121 C138
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1 C101_130121 C101
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1 C58_290121  C58
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 C190_010221 C190
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 C170_020221 C170
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1 C101_180121 C101
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 C146_140121 C146
#                                                  case_control WHO_temp_severity
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 POSITIVE     moderate
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 POSITIVE     moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 POSITIVE     critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 POSITIVE     mild
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 POSITIVE     severe
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 POSITIVE     severe
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 POSITIVE     mild
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 POSITIVE     moderate
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 POSITIVE     moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 POSITIVE     mild
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 POSITIVE     mild
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 POSITIVE     mild
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 POSITIVE     mild
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 POSITIVE     mild
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 POSITIVE     mild
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 POSITIVE     mild
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 POSITIVE     moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 POSITIVE     mild
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 POSITIVE     moderate
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 POSITIVE     mild
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 POSITIVE     moderate
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 POSITIVE     moderate
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1 POSITIVE     moderate
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1 POSITIVE     mild
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1 POSITIVE     severe
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1 POSITIVE     moderate
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1 POSITIVE     critical
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 POSITIVE     mild
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1 POSITIVE     moderate
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1 POSITIVE     moderate
# ⋮                                                ⋮            ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1 POSITIVE     mild
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 POSITIVE     mild
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1 POSITIVE     severe
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1 POSITIVE     severe
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1 POSITIVE     mild
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1 POSITIVE     critical
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 POSITIVE     mild
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 POSITIVE     mild
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1 POSITIVE     moderate
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1 POSITIVE     mild
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1 POSITIVE     mild
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 POSITIVE     mild
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1 POSITIVE     mild
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1 POSITIVE     severe
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 POSITIVE     moderate
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1 POSITIVE     mild
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1 POSITIVE     moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 POSITIVE     mild
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 POSITIVE     mild
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 POSITIVE     moderate
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1 POSITIVE     moderate
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1 POSITIVE     mild
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 POSITIVE     mild
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 POSITIVE     mild
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1 POSITIVE     moderate
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 POSITIVE     mild
#                                                  WHO_temp_severity_group
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1 mild_moderate
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1 mild_moderate
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1 severe_critical
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1 mild_moderate
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1 severe_critical
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 mild_moderate
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1 mild_moderate
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1 mild_moderate
# ⋮                                                ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1 severe_critical
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1 severe_critical
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 mild_moderate
#                                                  WHO_severity_group
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 severe_critical
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 severe_critical
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 severe_critical
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1 severe_critical
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1 severe_critical
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1 severe_critical
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1 mild_moderate
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1 severe_critical
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 mild_moderate
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1 mild_moderate
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1 mild_moderate
# ⋮                                                ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1 severe_critical
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1 severe_critical
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1 severe_critical
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1 severe_critical
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1 severe_critical
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1 severe_critical
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1 severe_critical
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 severe_critical
#                                                  grouped_temp_severity
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 mild_moderate
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1 mild_moderate
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1 mild_moderate
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1 severe_critical
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1 mild_moderate
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1 severe_critical
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 mild_moderate
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1 mild_moderate
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1 mild_moderate
# ⋮                                                ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1 severe_critical
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1 severe_critical
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 mild_moderate
#                                                  grouped_severity sex ethnicity
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1 severe_critical  M   asian
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 mild_moderate    M   white
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 severe_critical  M   black
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1 mild_moderate    M   asian
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1 severe_critical  M   asian
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1 severe_critical  M   asian
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1 mild_moderate    M   asian
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1 mild_moderate    M   asian
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1 mild_moderate    F   other
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1 mild_moderate    M   asian
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1 mild_moderate    M   asian
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1 mild_moderate    F   other
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1 mild_moderate    M   asian
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1 mild_moderate    M   asian
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1 mild_moderate    F   asian
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1 mild_moderate    M   asian
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1 mild_moderate    F   other
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1 mild_moderate    F   asian
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1 severe_critical  M   asian
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1 mild_moderate    M   asian
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1 severe_critical  M   asian
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1 mild_moderate    F   asian
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1 severe_critical  M   white
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1 severe_critical  M   asian
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1 severe_critical  M   white
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1 mild_moderate    F   asian
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1 severe_critical  M   white
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 mild_moderate    F   black
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1 mild_moderate    F   asian
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1 mild_moderate    F   asian
# ⋮                                                ⋮                ⋮   ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1 mild_moderate    F   asian
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate    M   other
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate    M   asian
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1 severe_critical  M   asian
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate    M   white
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1 mild_moderate    M   other
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1 severe_critical  M   asian
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1 mild_moderate    F   white
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1 mild_moderate    M   asian
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1 severe_critical  M   asian
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate    M   white
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate    M   other
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1 severe_critical  F   white
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1 mild_moderate    F   white
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1 severe_critical  M   asian
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate    M   white
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1 mild_moderate    F   white
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1 severe_critical  M   asian
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate    F   asian
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1 mild_moderate    F   white
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1 severe_critical  M   black
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate    F   asian
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate    F   asian
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate    F   asian
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1 severe_critical  M   asian
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1 mild_moderate    F   white
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate    M   white
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate    M   asian
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1 severe_critical  M   asian
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 severe_critical  M   asian
#                                                  age_scaled   centre
# UK-CIC10689738+UK-CIC10690026_AACACGTGTTGGTGGA-1  0.30051451  NCL
# UK-CIC10689740+UK-CIC10690028_AAACGGGAGCTCCTCT-1 -1.21957771  NCL
# UK-CIC10689740+UK-CIC10690028_AAAGCAATCAACACAC-1 -0.22567126  NCL
# UK-CIC10689742+UK-CIC10690030_AAACCTGGTCAAAGCG-1  1.17749078  NCL
# UK-CIC10689742+UK-CIC10690030_AAAGTAGTCCCACTTG-1  0.30051451  NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGCAGGACGTA-1  0.30051451  NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGCATCGATTG-1  0.18358434  NCL
# UK-CIC10689744+UK-CIC10690032_AAACCTGTCCAGAAGG-1  1.17749078  NCL
# UK-CIC10689746+UK-CIC10690034_AAAGATGGTACAAGTA-1  0.47590976  NCL
# UK-CIC10689746+UK-CIC10690034_AAAGCAAAGCTGCGAA-1  1.17749078  NCL
# UK-CIC10689746+UK-CIC10690034_AAAGCAAGTTGCGTTA-1  0.18358434  NCL
# UK-CIC10689748+UK-CIC10690036_AAACCTGTCGTGACAT-1  0.47590976  NCL
# UK-CIC10689748+UK-CIC10690036_AAAGATGCAGCGTTCG-1  0.65130502  NCL
# UK-CIC10689748+UK-CIC10690036_AAAGCAAGTACCGGCT-1  0.18358434  NCL
# UK-CIC10689750+UK-CIC10690038_AAACGGGGTCTCTCGT-1  0.94363044  NCL
# UK-CIC10689750+UK-CIC10690038_AAACGGGTCTACCAGA-1  0.65130502  NCL
# UK-CIC10689750+UK-CIC10690038_AAAGATGGTAAATGTG-1  0.47590976  NCL
# UK-CIC10689752+UK-CIC10690040_AAACCTGAGTCTCAAC-1  0.94363044  NCL
# UK-CIC10689752+UK-CIC10690040_AAACCTGCAATCGAAA-1  0.06665417  NCL
# UK-CIC10689752+UK-CIC10690040_AAAGCAATCTGCTGTC-1  0.65130502  NCL
# UK-CIC10689754+UK-CIC10690042_AAACCTGAGGTGGGTT-1  0.06665417  NCL
# UK-CIC10689754+UK-CIC10690042_AAACGGGGTGTAAGTA-1  0.94363044  NCL
# UK-CIC10689754+UK-CIC10690042_AAATGCCGTGCAACTT-1  1.11902570  NCL
# UK-CIC10689756+UK-CIC10690044_AAACCTGAGGAGTCTG-1  0.06665417  NCL
# UK-CIC10689756+UK-CIC10690044_AAACCTGTCTACTATC-1  1.11902570  NCL
# UK-CIC10689756+UK-CIC10690044_AAAGATGAGATGAGAG-1  1.00209553  NCL
# UK-CIC10689758+UK-CIC10690046_AAACCTGTCGGCGGTT-1  1.11902570  NCL
# UK-CIC10689758+UK-CIC10690046_AAAGATGTCAATCACG-1 -1.27804279  NCL
# UK-CIC10689758+UK-CIC10690046_AACTGGTCAAGTACCT-1  1.00209553  NCL
# UK-CIC10689760+UK-CIC10690048_AAACCTGAGGGTCGAT-1  1.00209553  NCL
# ⋮                                                ⋮            ⋮
# UK-CIC10690357+UK-CIC10690549_AACACGTCACGGTTTA-1  0.709770104 Cambridge
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1  0.534374849 Cambridge
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1  1.235955870 Cambridge
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGAGAACG-1  0.826700274 Cambridge
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 -0.401066514 Cambridge
# UK-CIC10690361+UK-CIC10690553_AAGCCGCGTCCCTACT-1  0.534374849 Cambridge
# UK-CIC10690361+UK-CIC10690553_AAGGAGCGTGATAAAC-1  0.008189082 Cambridge
# UK-CIC10690361+UK-CIC10690553_ACAGCTAGTTACGTCA-1  0.651305019 Cambridge
# UK-CIC10690361+UK-CIC10690553_ACGGGCTCAGACGCCT-1  1.235955870 Cambridge
# UK-CIC10690365+UK-CIC10690557_AAAGTAGTCAACACGT-1  0.826700274 Cambridge
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 -0.401066514 Cambridge
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1  0.534374849 Cambridge
# UK-CIC10690365+UK-CIC10690557_ACACCCTTCAGGCCCA-1  1.060560615 Cambridge
# UK-CIC10690365+UK-CIC10690557_ACGGGCTGTAAATGAC-1  0.651305019 Cambridge
# UK-CIC10690369+UK-CIC10690561_AAAGATGAGCCTCGTG-1  0.826700274 Cambridge
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 -0.401066514 Cambridge
# UK-CIC10690369+UK-CIC10690561_AAGGAGCAGAAACGAG-1  0.651305019 Cambridge
# UK-CIC10690373+UK-CIC10690565_AAACCTGGTTGCGCAC-1  0.008189082 Cambridge
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1  0.943630444 Cambridge
# UK-CIC10690373+UK-CIC10690565_AATCCAGCAGATAATG-1  0.651305019 Cambridge
# UK-CIC10690377+UK-CIC10690569_AAACCTGAGCGATTCT-1  1.411351125 Cambridge
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 -2.213484152 Cambridge
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 -0.050276003 Cambridge
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1  0.943630444 Cambridge
# UK-CIC10690377+UK-CIC10690569_AAGGCAGCAGTCGTGC-1  0.008189082 Cambridge
# UK-CIC10690377+UK-CIC10690569_AATCGGTGTTCAGTAC-1  0.651305019 Cambridge
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 -0.401066514 Cambridge
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1  1.235955870 Cambridge
# UK-CIC10690381+UK-CIC10690573_AAAGTAGAGATGAGAG-1  0.008189082 Cambridge
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1  0.300514508 Cambridge

# %%
library(lmerTest)
library(pbmcapply)
# Out:
# Loading required package: lme4
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
res <- as.list(1:nrow(nhoodCounts(mylo)))
res <- pbmclapply(res, function(x) glmer.nb(nhoodCounts(mylo)[x,] ~ grouped_temp_severity + sex + ethnicity + age_scaled + (1|individual_id), offset = log(colSums(nhoodCounts(mylo))), data = metadata, control=glmerControl(check.conv.singular = .makeCC(action = "ignore",  tol = 1e-2), optimizer="bobyqa", tol=1e-02)), mc.cores = parallel::detectCores())
res_summary <- pbmclapply(res, summary)
save(res_summary, res, metadata, file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_no_nas_milo_results.RData')

# %%
# load(file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_no_nas_milo_results.RData')

# %%
# example coefficients for 1 neighborhood
res_summary[[1]]$coefficients
# Out:
#                                      Estimate      Std. Error z value
# (Intercept)                          -9.4092416798 0.3262877  -28.837255069
# grouped_temp_severitysevere_critical -1.2478936763 0.6892309   -1.810559691
# sexM                                 -0.2535358309 0.4007443   -0.632662291
# ethnicityblack                       -0.5494104181 0.8358222   -0.657329304
# ethnicityother                        0.0797675363 0.6774019    0.117755115
# ethnicitywhite                        0.0007120539 0.4188506    0.001700019
# age_scaled                            0.5309303635 0.2203603    2.409373517
#                                      Pr(>|z|)
# (Intercept)                          7.321196e-183
# grouped_temp_severitysevere_critical  7.020904e-02
# sexM                                  5.269542e-01
# ethnicityblack                        5.109692e-01
# ethnicityother                        9.062617e-01
# ethnicitywhite                        9.986436e-01
# age_scaled                            1.597993e-02

# %%
singulars <- lapply(res, function(x) as.numeric(isSingular(x)))
conv <- lapply(res, function(x) length(slot(x, "optinfo")$conv$lme4$messages))

# %%
pvalue <- pbmclapply(res_summary, function(x) x$coefficients[2,4])
beta <- pbmclapply(res_summary, function(x) x$coefficients[2,1])

# %%
da.res = data.frame(Nhood = as.numeric(1:nrow(nhoodCounts(mylo))), beta = do.call(c, beta), PValue = do.call(c, pvalue))

# %%
da.res$Singular <- singulars
da.res$Conv <- conv

# %%
da.res$SpatialFDR <- graphSpatialFDR(x.nhoods=nhoods(mylo), graph=miloR::graph(mylo),
    weighting='k-distance', pvalues=da.res$PValue,
    indices=nhoodIndex(mylo), distances=nhoodDistances(mylo),
    reduced.dimensions=reducedDim(mylo, 'X_scVI'), k = 50)
da.res$Diff <- sign(da.res$beta)
da.res$Diff[da.res$SpatialFDR >= 0.1 | da.res$Singular > 0 | da.res$Conv > 0] <- 0
saveRDS(da.res, file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_no_nas_milo_results_DA.RDS')

# %%
table(da.res$Diff)
# Out:
#    -1     0     1
#     1 11615    11

# %%
library(ggbeeswarm)
library(ggplot2)
new_DA_beeswarm <- function (da.res1, da.res2 = NULL, max = 5, color.by = 'SpatialFDR', group.by = NULL, split.by =NULL, alpha = 0.1, subset.nhoods = NULL, size = 2, filter = c('Mixed', 'doublets')) {
    if (!is.null(da.res2) && !is.null(split.by)){
        da.res1$split = split.by[1]
        da.res2$split = split.by[2]
        da.res <- rbind(da.res1, da.res2)
    } else {
        da.res <- da.res1
    }

    da.res$beta[da.res$beta > max] <- max
    da.res$beta[da.res$beta < -max] <- -max
    da.res <- da.res %>% filter(!get(group.by) %in% filter)
    if (!is.null(group.by)) {
        if (!group.by %in% colnames(da.res)) {
            stop(paste0(group.by, " is not a column in da.res. Have you forgot to run annotateNhoods(x, da.res, ", 
                group.by, ")?"))
        }
        if (is.numeric(da.res[, group.by])) {
            stop(paste0(group.by, " is a numeric variable. Please bin to use for grouping."))
        }
        da.res <- mutate(da.res, group_by = da.res[, group.by])
    }else {
        da.res <- mutate(da.res, group_by = "g1")
    }    
    if (!is.factor(da.res[, "group_by"])) {
        message(paste0("Converting group.by to factor..."))
        da.res <- mutate(da.res, factor(group_by, levels = unique(group_by)))
    }
    if (!is.null(subset.nhoods)) {
        da.res <- da.res[subset.nhoods, ]
    }
    
    da.res <- da.res %>% mutate(is_signif = ifelse((get(color.by) < alpha & get('Singular') < 1 & get('Conv') < 1), 
        1, 0)) %>% mutate(beta_color = ifelse(is_signif == 1, 
        beta, NA)) %>% arrange(group_by) %>% mutate(Nhood = factor(Nhood, 
        levels = unique(Nhood)))
    if (!is.null(split.by)){
        p <- ggplot(da.res, aes(group_by, beta, color = beta_color)) + 
            scale_color_gradient2(midpoint = 0, low = "#0571b0", mid = '#f7f7f7', high = "#ca0020", limits=c(-max/3, max/3), oob=scales::squish) +
            guides(color = "none") + 
            xlab(group.by) + 
            ylab("beta") + 
            geom_quasirandom(alpha = 1, size = size) +
            coord_flip() + 
            theme_bw() + 
            theme(axis.title.y = element_blank(),
                  axis.title.x = element_text(size=20, color = '#000000'),
                  axis.text = element_text(size=20, color = '#000000'),
                  axis.ticks = element_line(color = '#000000'),
                  panel.border = element_rect(colour = "#000000")
                ) + 
            facet_wrap(split~.) +
            theme(strip.background = element_blank(), strip.text.x = element_text(angle = 0, size = 20, color = '#000000'))
    } else {
        p <- ggplot(da.res, aes(group_by, beta, color = beta_color)) + 
        scale_color_gradient2(midpoint = 0, low = "#0571b0", mid = '#f7f7f7', high = "#ca0020", limits=c(-max/3, max/3), oob=scales::squish) +
        guides(color = "none") + 
        xlab(group.by) + 
        ylab("beta") + 
        geom_quasirandom(alpha = 1, size = size) +
        coord_flip() + 
        theme_bw() + 
        theme(axis.title.y = element_blank(),
              axis.title.x = element_text(size=20, color = '#000000'),
              axis.text = element_text(size=20, color = '#000000'),
              axis.ticks = element_line(color = '#000000'),
              panel.border = element_rect(colour = "#000000")
            ) + 
        theme(strip.background = element_blank(), strip.text.x = element_text(angle = 0, size = 20, color = '#000000'))
    }
    
    p$data <- p$data[order(p$data$beta_color, na.last = FALSE), ]
    return(p)
}
# Out:
# Loading required package: ggplot2

# %%
# options(repr.plot.width=20, repr.plot.height=10)
da.res <- annotateNhoods(mylo, da.res, coldata_col = "celltype_B_corrected")
da.res$celltype_B_corrected <- ifelse(da.res$celltype_B_corrected_fraction < 0.7, "Mixed", da.res$celltype_B_corrected)
p <- new_DA_beeswarm(da.res, color.by = 'SpatialFDR', group.by = "celltype_B_corrected", size = 2, alpha = .05)
p
# Out:
# Converting group.by to factor...
# plot without title

# %%
# options(repr.plot.width=20, repr.plot.height=10)
da.res <- annotateNhoods(mylo, da.res, coldata_col = "celltype_B_corrected_IFN")
da.res$celltype_B_corrected_IFN <- ifelse(da.res$celltype_B_corrected_IFN_fraction < 0.7, "Mixed", da.res$celltype_B_corrected_IFN)
p <- new_DA_beeswarm(da.res, color.by = 'SpatialFDR', group.by = "celltype_B_corrected_IFN", size = 2, alpha = .05)
p
# Out:
# Converting group.by to factor...
# plot without title
