# %%
library(miloR)
library(igraph)
library(BiocParallel)
library(SingleCellExperiment)
library(Matrix)
library(dplyr)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal')
# Out:
# Loading required package: edgeR
#
# Loading required package: limma
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:miloR’:
#
#     graph
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:igraph’:
#
#     normalize, path, union
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SingleCellExperiment’
#
#
# The following object is masked from ‘package:edgeR’:
#
#     cpm
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:igraph’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
load('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_pos_vs_neg_milo_prep_230622.RData')
adata_no_knnx
# Out:
# class: SingleCellExperiment
# dim: 33559 26458
# metadata(10): WHO_temp_severity_colors case_control_colors ...
#   initial_cluster_B_colors seurat_clusters_colors
# assays(2): X counts
# rownames(33559): MIR1302-2HG FAM138A ... VIRAL-Cytomegalovieus-(CMV)
#   VIRAL-SARS-CoV2
# rowData names(5): vst.mean vst.variance vst.variance.expected
#   vst.variance.standardized vst.variable
# colnames(26458): UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1
#   UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 ...
#   UK-CIC10690384+UK-CIC10690576_TTTGGTTGTACGAAAT-1
#   UK-CIC10690384+UK-CIC10690576_TTTGGTTGTTGTCTTT-1
# colData names(70): orig.ident nCount_RNA ... time_from_positive_swab
#   time_from_infection
# reducedDimNames(6): X_harmony_rna X_pca_rna ... X_umapafterharmony_rna
#   X_umapbeforeharmony_rna
# altExpNames(0):

# %%
mylo <- Milo(adata_no_knnx)
milo_graph <- buildFromAdjacency(knn_adjacencyx, k=50, is.binary=TRUE)
miloR::graph(mylo) <- miloR::graph(milo_graph)

# %%
dim(reducedDims(mylo)[['X_scVI']])
# Out:
# [1] 26458    10

# %%
mylo <- buildGraph(mylo, k=50, d=10, reduced.dim="X_scVI", BPPARAM = MulticoreParam(workers = 24, progressbar = TRUE))
mylo <- makeNhoods(mylo, prop = 0.3, k=50, d=10, reduced_dim="X_scVI")
# Out:
#   |======================================================================| 100%
# Constructing kNN graph with k:50
#
# Checking valid object

# %%
mylo <- countCells_(mylo, meta.data = data.frame(colData(mylo)), samples="sample_id")
mylo <- calcNhoodDistance(mylo, d=10, reduced.dim = 'X_scVI', use.assay = 'counts')
mylo <- buildNhoodGraph(mylo)
saveRDS(mylo, 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_pos_vs_neg_milo_230622.RDS')
# Out:
# Checking meta.data validity
#
# Counting cells in neighbourhoods

# %%
# kernel died...
library(miloR)
library(igraph)
library(BiocParallel)
library(SingleCellExperiment)
library(Matrix)
library(dplyr)
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal')

# %%
mylo <- readRDS('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_pos_vs_neg_milo_230622.RDS')
metadata = data.frame(colData(mylo))

# %%
# metadata$case_control <- ordered(factor(metadata$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY')))
metadata$case_control <- factor(metadata$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY'))
metadata$WHO_temp_severity <- factor(metadata$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'))
metadata$WHO_temp_severity_group <- factor(metadata$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical'))
metadata$WHO_severity_group <- factor(metadata$WHO_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical')) # interpreted as peak severity
metadata$grouped_temp_severity <- ifelse(metadata$WHO_temp_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
metadata$grouped_severity <- ifelse(metadata$WHO_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
metadata$age_scaled <- scale(metadata$calc_age) # scale age
metadata$corrected_ethnicity = factor(metadata$corrected_ethnicity)
metadata$sex = factor(metadata$sex)
metadata$centre = factor(metadata$centre)

# %%
# remove 
metadata <- distinct(metadata[, c('sample_id', 'individual_id', 'case_control', 'WHO_temp_severity', 'WHO_temp_severity_group', 'WHO_severity_group', 'grouped_temp_severity', 'grouped_severity', 'sex', 'corrected_ethnicity', 'age_scaled', 'centre', 'PC1_nonafricanVsAfrican', 'PC2_asianVsEuropean')], .keep_all = TRUE)
metadata
# Out:
#                                                  sample_id individual_id
# UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1 C108_2201 C108
# UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 C138_0402 C138
# UK-CIC10690315+UK-CIC10690507_AACCGCGCACTCTGTC-1 C137_2801 C137
# UK-CIC10690315+UK-CIC10690507_AACGTTGAGGGCATGT-1 C140_2801 C140
# UK-CIC10690317+UK-CIC10690509_AAACGGGAGCGATTCT-1 C140_3001 C140
# UK-CIC10690317+UK-CIC10690509_AACTCCCTCTGATTCT-1 C108_1501 C108
# UK-CIC10690317+UK-CIC10690509_AACTGGTCAGTACACT-1 C138_0202 C138
# UK-CIC10690321+UK-CIC10690513_AAAGATGGTAGCTGCC-1 C140_1103 C140
# UK-CIC10690321+UK-CIC10690513_AAATGCCGTGGCAAAC-1 C137_2502 C137
# UK-CIC10690321+UK-CIC10690513_ACATACGAGGCCGAAT-1 C138_3001 C138
# UK-CIC10690321+UK-CIC10690513_ACGATACCATCTCCCA-1 C145_2301 C145
# UK-CIC10690321+UK-CIC10690513_ACGCCAGGTGGTTTCA-1 C108_2204 C108
# UK-CIC10690325+UK-CIC10690517_AAACCTGGTTAAGTAG-1 C140_0202 C140
# UK-CIC10690325+UK-CIC10690517_AAACGGGAGAACTGTA-1 C137_3004 C137
# UK-CIC10690325+UK-CIC10690517_AAAGCAAAGGATCGCA-1 C146_2502 C146
# UK-CIC10690325+UK-CIC10690517_AACCATGCAATTCCTT-1 C145_1901 C145
# UK-CIC10690325+UK-CIC10690517_AGCATACTCGCGCCAA-1 C138_2301 C138
# UK-CIC10690329+UK-CIC10690521_AAAGTAGAGGGTTCCC-1 C146_2701 C146
# UK-CIC10690329+UK-CIC10690521_AAATGCCAGGGTGTTG-1 C147_2801 C147
# UK-CIC10690329+UK-CIC10690521_AAATGCCCATTAGGCT-1 C140_0902 C140
# UK-CIC10690329+UK-CIC10690521_AGTCTTTGTAATTGGA-1 C138_3004 C138
# UK-CIC10690333+UK-CIC10690525_AAACGGGAGTTCGCAT-1 C140_0402 C140
# UK-CIC10690333+UK-CIC10690525_AAAGATGCAGCTGCAC-1 C146_1201 C146
# UK-CIC10690333+UK-CIC10690525_AAAGTAGAGGAATGGA-1 C145_0701 C145
# UK-CIC10690333+UK-CIC10690525_AAATGCCTCCAAGTAC-1 C168_0403 C168
# UK-CIC10690333+UK-CIC10690525_AACTCCCAGCTAGTGG-1 C147_2601 C147
# UK-CIC10690337+UK-CIC10690529_AAACCTGGTAAATGAC-1 C169_0403 C169
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1 C147_1401 C147
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1 C168_2001 C168
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1 C140_3004 C140
# ⋮                                                ⋮         ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1 C168_3001 C168
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1 C170_2601 C170
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1 C169_2601 C169
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 C190_2901 C190
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1 C147_3004 C147
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1 C170_0402 C170
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 C187_2601 C187
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 C190_1002 C190
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1 C168_1205 C168
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 C187_1401 C187
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1 C169_3001 C169
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 C170_3001 C170
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1 C169_1205 C169
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 C190_0302 C190
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 C187_1901 C187
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1 C170_2801 C170
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 C190_0802 C190
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 C187_2301 C187
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 C108_1801 C108
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1 C170_1205 C170
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1 C187_2605 C187
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 C190_0502 C190
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 C138_2801 C138
# UK-CIC10690373+UK-CIC10690565_AAGCCGCCATCGGACC-1 C190_2605 C190
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 C140_0602 C140
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 C137_1901 C137
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 C138_2601 C138
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 C190_0102 C190
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 C170_0202 C170
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 C146_1401 C146
#                                                  case_control WHO_temp_severity
# UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1 POSITIVE     moderate
# UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 POSITIVE     mild
# UK-CIC10690315+UK-CIC10690507_AACCGCGCACTCTGTC-1 POSITIVE     mild
# UK-CIC10690315+UK-CIC10690507_AACGTTGAGGGCATGT-1 POSITIVE     mild
# UK-CIC10690317+UK-CIC10690509_AAACGGGAGCGATTCT-1 POSITIVE     mild
# UK-CIC10690317+UK-CIC10690509_AACTCCCTCTGATTCT-1 POSITIVE     moderate
# UK-CIC10690317+UK-CIC10690509_AACTGGTCAGTACACT-1 POSITIVE     mild
# UK-CIC10690321+UK-CIC10690513_AAAGATGGTAGCTGCC-1 RECOVERY     NA
# UK-CIC10690321+UK-CIC10690513_AAATGCCGTGGCAAAC-1 RECOVERY     NA
# UK-CIC10690321+UK-CIC10690513_ACATACGAGGCCGAAT-1 POSITIVE     moderate
# UK-CIC10690321+UK-CIC10690513_ACGATACCATCTCCCA-1 POSITIVE     moderate
# UK-CIC10690321+UK-CIC10690513_ACGCCAGGTGGTTTCA-1 NEGATIVE     NA
# UK-CIC10690325+UK-CIC10690517_AAACCTGGTTAAGTAG-1 POSITIVE     mild
# UK-CIC10690325+UK-CIC10690517_AAACGGGAGAACTGTA-1 NEGATIVE     NA
# UK-CIC10690325+UK-CIC10690517_AAAGCAAAGGATCGCA-1 RECOVERY     NA
# UK-CIC10690325+UK-CIC10690517_AACCATGCAATTCCTT-1 POSITIVE     moderate
# UK-CIC10690325+UK-CIC10690517_AGCATACTCGCGCCAA-1 POSITIVE     moderate
# UK-CIC10690329+UK-CIC10690521_AAAGTAGAGGGTTCCC-1 POSITIVE     moderate
# UK-CIC10690329+UK-CIC10690521_AAATGCCAGGGTGTTG-1 POSITIVE     critical
# UK-CIC10690329+UK-CIC10690521_AAATGCCCATTAGGCT-1 POSITIVE     mild
# UK-CIC10690329+UK-CIC10690521_AGTCTTTGTAATTGGA-1 NEGATIVE     NA
# UK-CIC10690333+UK-CIC10690525_AAACGGGAGTTCGCAT-1 POSITIVE     mild
# UK-CIC10690333+UK-CIC10690525_AAAGATGCAGCTGCAC-1 POSITIVE     mild
# UK-CIC10690333+UK-CIC10690525_AAAGTAGAGGAATGGA-1 POSITIVE     mild
# UK-CIC10690333+UK-CIC10690525_AAATGCCTCCAAGTAC-1 RECOVERY     NA
# UK-CIC10690333+UK-CIC10690525_AACTCCCAGCTAGTGG-1 POSITIVE     critical
# UK-CIC10690337+UK-CIC10690529_AAACCTGGTAAATGAC-1 RECOVERY     NA
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1 POSITIVE     mild
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1 POSITIVE     mild
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1 NEGATIVE     NA
# ⋮                                                ⋮            ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1 POSITIVE     mild
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1 POSITIVE     mild
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1 POSITIVE     mild
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 POSITIVE     mild
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1 NEGATIVE     NA
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1 POSITIVE     mild
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 POSITIVE     mild
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 POSITIVE     mild
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1 NEGATIVE     NA
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 POSITIVE     mild
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1 POSITIVE     mild
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1 NEGATIVE     NA
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 POSITIVE     mild
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1 POSITIVE     mild
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 POSITIVE     mild
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 POSITIVE     mild
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 POSITIVE     moderate
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1 NEGATIVE     NA
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1 NEGATIVE     NA
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 POSITIVE     mild
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 POSITIVE     moderate
# UK-CIC10690373+UK-CIC10690565_AAGCCGCCATCGGACC-1 NEGATIVE     NA
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 POSITIVE     mild
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 POSITIVE     mild
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 POSITIVE     moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 POSITIVE     mild
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 POSITIVE     mild
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 POSITIVE     mild
#                                                  WHO_temp_severity_group
# UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AACCGCGCACTCTGTC-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AACGTTGAGGGCATGT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AAACGGGAGCGATTCT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AACTCCCTCTGATTCT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AACTGGTCAGTACACT-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_AAAGATGGTAGCTGCC-1 NA
# UK-CIC10690321+UK-CIC10690513_AAATGCCGTGGCAAAC-1 NA
# UK-CIC10690321+UK-CIC10690513_ACATACGAGGCCGAAT-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_ACGATACCATCTCCCA-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_ACGCCAGGTGGTTTCA-1 NA
# UK-CIC10690325+UK-CIC10690517_AAACCTGGTTAAGTAG-1 mild_moderate
# UK-CIC10690325+UK-CIC10690517_AAACGGGAGAACTGTA-1 NA
# UK-CIC10690325+UK-CIC10690517_AAAGCAAAGGATCGCA-1 NA
# UK-CIC10690325+UK-CIC10690517_AACCATGCAATTCCTT-1 mild_moderate
# UK-CIC10690325+UK-CIC10690517_AGCATACTCGCGCCAA-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AAAGTAGAGGGTTCCC-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AAATGCCAGGGTGTTG-1 severe_critical
# UK-CIC10690329+UK-CIC10690521_AAATGCCCATTAGGCT-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AGTCTTTGTAATTGGA-1 NA
# UK-CIC10690333+UK-CIC10690525_AAACGGGAGTTCGCAT-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAAGATGCAGCTGCAC-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAAGTAGAGGAATGGA-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAATGCCTCCAAGTAC-1 NA
# UK-CIC10690333+UK-CIC10690525_AACTCCCAGCTAGTGG-1 severe_critical
# UK-CIC10690337+UK-CIC10690529_AAACCTGGTAAATGAC-1 NA
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1 mild_moderate
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1 mild_moderate
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1 NA
# ⋮                                                ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1 mild_moderate
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1 NA
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1 mild_moderate
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1 NA
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1 NA
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1 NA
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1 NA
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAGCCGCCATCGGACC-1 NA
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 mild_moderate
#                                                  WHO_severity_group
# UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1 severe_critical
# UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AACCGCGCACTCTGTC-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AACGTTGAGGGCATGT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AAACGGGAGCGATTCT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AACTCCCTCTGATTCT-1 severe_critical
# UK-CIC10690317+UK-CIC10690509_AACTGGTCAGTACACT-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_AAAGATGGTAGCTGCC-1 NA
# UK-CIC10690321+UK-CIC10690513_AAATGCCGTGGCAAAC-1 NA
# UK-CIC10690321+UK-CIC10690513_ACATACGAGGCCGAAT-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_ACGATACCATCTCCCA-1 severe_critical
# UK-CIC10690321+UK-CIC10690513_ACGCCAGGTGGTTTCA-1 NA
# UK-CIC10690325+UK-CIC10690517_AAACCTGGTTAAGTAG-1 mild_moderate
# UK-CIC10690325+UK-CIC10690517_AAACGGGAGAACTGTA-1 NA
# UK-CIC10690325+UK-CIC10690517_AAAGCAAAGGATCGCA-1 NA
# UK-CIC10690325+UK-CIC10690517_AACCATGCAATTCCTT-1 severe_critical
# UK-CIC10690325+UK-CIC10690517_AGCATACTCGCGCCAA-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AAAGTAGAGGGTTCCC-1 severe_critical
# UK-CIC10690329+UK-CIC10690521_AAATGCCAGGGTGTTG-1 severe_critical
# UK-CIC10690329+UK-CIC10690521_AAATGCCCATTAGGCT-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AGTCTTTGTAATTGGA-1 NA
# UK-CIC10690333+UK-CIC10690525_AAACGGGAGTTCGCAT-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAAGATGCAGCTGCAC-1 severe_critical
# UK-CIC10690333+UK-CIC10690525_AAAGTAGAGGAATGGA-1 severe_critical
# UK-CIC10690333+UK-CIC10690525_AAATGCCTCCAAGTAC-1 NA
# UK-CIC10690333+UK-CIC10690525_AACTCCCAGCTAGTGG-1 severe_critical
# UK-CIC10690337+UK-CIC10690529_AAACCTGGTAAATGAC-1 NA
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1 severe_critical
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1 mild_moderate
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1 NA
# ⋮                                                ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1 mild_moderate
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1 NA
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1 mild_moderate
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1 NA
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1 NA
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 severe_critical
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1 NA
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1 NA
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAGCCGCCATCGGACC-1 NA
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 severe_critical
#                                                  grouped_temp_severity
# UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AACCGCGCACTCTGTC-1 mild_moderate
# UK-CIC10690315+UK-CIC10690507_AACGTTGAGGGCATGT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AAACGGGAGCGATTCT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AACTCCCTCTGATTCT-1 mild_moderate
# UK-CIC10690317+UK-CIC10690509_AACTGGTCAGTACACT-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_AAAGATGGTAGCTGCC-1 severe_critical
# UK-CIC10690321+UK-CIC10690513_AAATGCCGTGGCAAAC-1 severe_critical
# UK-CIC10690321+UK-CIC10690513_ACATACGAGGCCGAAT-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_ACGATACCATCTCCCA-1 mild_moderate
# UK-CIC10690321+UK-CIC10690513_ACGCCAGGTGGTTTCA-1 severe_critical
# UK-CIC10690325+UK-CIC10690517_AAACCTGGTTAAGTAG-1 mild_moderate
# UK-CIC10690325+UK-CIC10690517_AAACGGGAGAACTGTA-1 severe_critical
# UK-CIC10690325+UK-CIC10690517_AAAGCAAAGGATCGCA-1 severe_critical
# UK-CIC10690325+UK-CIC10690517_AACCATGCAATTCCTT-1 mild_moderate
# UK-CIC10690325+UK-CIC10690517_AGCATACTCGCGCCAA-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AAAGTAGAGGGTTCCC-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AAATGCCAGGGTGTTG-1 severe_critical
# UK-CIC10690329+UK-CIC10690521_AAATGCCCATTAGGCT-1 mild_moderate
# UK-CIC10690329+UK-CIC10690521_AGTCTTTGTAATTGGA-1 severe_critical
# UK-CIC10690333+UK-CIC10690525_AAACGGGAGTTCGCAT-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAAGATGCAGCTGCAC-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAAGTAGAGGAATGGA-1 mild_moderate
# UK-CIC10690333+UK-CIC10690525_AAATGCCTCCAAGTAC-1 severe_critical
# UK-CIC10690333+UK-CIC10690525_AACTCCCAGCTAGTGG-1 severe_critical
# UK-CIC10690337+UK-CIC10690529_AAACCTGGTAAATGAC-1 severe_critical
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1 mild_moderate
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1 mild_moderate
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1 severe_critical
# ⋮                                                ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1 mild_moderate
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 mild_moderate
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1 severe_critical
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1 mild_moderate
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1 severe_critical
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1 mild_moderate
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1 severe_critical
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 mild_moderate
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 mild_moderate
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1 severe_critical
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1 severe_critical
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1 mild_moderate
# UK-CIC10690373+UK-CIC10690565_AAGCCGCCATCGGACC-1 severe_critical
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1 mild_moderate
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1 mild_moderate
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1 mild_moderate
#                                                  grouped_severity sex
# UK-CIC10690315+UK-CIC10690507_AAACCTGAGCGATTCT-1 severe_critical  F
# UK-CIC10690315+UK-CIC10690507_AAAGCAATCTAACTGG-1 mild_moderate    F
# UK-CIC10690315+UK-CIC10690507_AACCGCGCACTCTGTC-1 mild_moderate    F
# UK-CIC10690315+UK-CIC10690507_AACGTTGAGGGCATGT-1 mild_moderate    F
# UK-CIC10690317+UK-CIC10690509_AAACGGGAGCGATTCT-1 mild_moderate    F
# UK-CIC10690317+UK-CIC10690509_AACTCCCTCTGATTCT-1 severe_critical  F
# UK-CIC10690317+UK-CIC10690509_AACTGGTCAGTACACT-1 mild_moderate    F
# UK-CIC10690321+UK-CIC10690513_AAAGATGGTAGCTGCC-1 severe_critical  F
# UK-CIC10690321+UK-CIC10690513_AAATGCCGTGGCAAAC-1 severe_critical  F
# UK-CIC10690321+UK-CIC10690513_ACATACGAGGCCGAAT-1 mild_moderate    F
# UK-CIC10690321+UK-CIC10690513_ACGATACCATCTCCCA-1 severe_critical  F
# UK-CIC10690321+UK-CIC10690513_ACGCCAGGTGGTTTCA-1 severe_critical  F
# UK-CIC10690325+UK-CIC10690517_AAACCTGGTTAAGTAG-1 mild_moderate    F
# UK-CIC10690325+UK-CIC10690517_AAACGGGAGAACTGTA-1 severe_critical  F
# UK-CIC10690325+UK-CIC10690517_AAAGCAAAGGATCGCA-1 severe_critical  M
# UK-CIC10690325+UK-CIC10690517_AACCATGCAATTCCTT-1 severe_critical  F
# UK-CIC10690325+UK-CIC10690517_AGCATACTCGCGCCAA-1 mild_moderate    F
# UK-CIC10690329+UK-CIC10690521_AAAGTAGAGGGTTCCC-1 severe_critical  M
# UK-CIC10690329+UK-CIC10690521_AAATGCCAGGGTGTTG-1 severe_critical  M
# UK-CIC10690329+UK-CIC10690521_AAATGCCCATTAGGCT-1 mild_moderate    F
# UK-CIC10690329+UK-CIC10690521_AGTCTTTGTAATTGGA-1 severe_critical  F
# UK-CIC10690333+UK-CIC10690525_AAACGGGAGTTCGCAT-1 mild_moderate    F
# UK-CIC10690333+UK-CIC10690525_AAAGATGCAGCTGCAC-1 severe_critical  M
# UK-CIC10690333+UK-CIC10690525_AAAGTAGAGGAATGGA-1 severe_critical  F
# UK-CIC10690333+UK-CIC10690525_AAATGCCTCCAAGTAC-1 severe_critical  M
# UK-CIC10690333+UK-CIC10690525_AACTCCCAGCTAGTGG-1 severe_critical  M
# UK-CIC10690337+UK-CIC10690529_AAACCTGGTAAATGAC-1 severe_critical  F
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1 severe_critical  M
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1 mild_moderate    M
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1 severe_critical  F
# ⋮                                                ⋮                ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1 mild_moderate    M
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1 mild_moderate    M
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1 mild_moderate    F
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 mild_moderate    M
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1 severe_critical  M
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1 mild_moderate    M
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 mild_moderate    M
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 mild_moderate    M
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1 severe_critical  M
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 mild_moderate    M
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1 mild_moderate    F
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1 mild_moderate    M
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1 severe_critical  F
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 mild_moderate    M
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 mild_moderate    M
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1 mild_moderate    M
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 mild_moderate    M
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 mild_moderate    M
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 severe_critical  F
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1 severe_critical  M
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGCTAACAA-1  22.79361
# UK-CIC10690337+UK-CIC10690529_AAACGGGAGGATGTAT-1  22.40497
# UK-CIC10690337+UK-CIC10690529_AAACGGGTCTTTAGGG-1  15.59963
# ⋮                                                ⋮
# UK-CIC10690349+UK-CIC10690541_ACAGCTACAGGTGGAT-1  22.40497
# UK-CIC10690349+UK-CIC10690541_ATTGGACAGAATGTTG-1  19.70217
# UK-CIC10690353+UK-CIC10690545_AAACCTGAGTGTGAAT-1  22.17921
# UK-CIC10690353+UK-CIC10690545_AAAGATGGTCTCTTAT-1 -44.82690
# UK-CIC10690353+UK-CIC10690545_AAGACCTCACTGTGTA-1  22.79361
# UK-CIC10690353+UK-CIC10690545_ACGAGCCGTCGCCATG-1  19.70217
# UK-CIC10690354+UK-CIC10690546_ATCACGATCAGGCCCA-1 -32.13882
# UK-CIC10690357+UK-CIC10690549_AAATGCCAGTTTCCTT-1 -44.82690
# UK-CIC10690357+UK-CIC10690549_AAATGCCTCAGCCTAA-1  22.40497
# UK-CIC10690357+UK-CIC10690549_AACACGTGTTAAGGGC-1 -32.13882
# UK-CIC10690357+UK-CIC10690549_AACTCCCCAGTCAGAG-1  22.17921
# UK-CIC10690357+UK-CIC10690549_AAGGAGCTCTGCTGCT-1  19.70217
# UK-CIC10690361+UK-CIC10690553_AAAGATGGTGATGTGG-1  22.17921
# UK-CIC10690361+UK-CIC10690553_AAAGTAGTCGCATGGC-1 -44.82690
# UK-CIC10690361+UK-CIC10690553_AACCGCGTCACTCCTG-1 -32.13882
# UK-CIC10690361+UK-CIC10690553_AGCCTAAGTCTTGCGG-1  19.70217
# UK-CIC10690365+UK-CIC10690557_AACGTTGGTTACAGAA-1 -44.82690
# UK-CIC10690365+UK-CIC10690557_AACTCAGAGACTTGAA-1 -32.13882
# UK-CIC10690365+UK-CIC10690557_CAAGAAAGTAAGGATT-1 -22.63690
# UK-CIC10690365+UK-CIC10690557_CCACTACCATAAAGGT-1  19.70217
# UK-CIC10690369+UK-CIC10690561_AACCATGCACGAGAGT-1 -32.13882
# UK-CIC10690369+UK-CIC10690561_AAGCCGCGTACCTACA-1 -44.82690
# UK-CIC10690373+UK-CIC10690565_AAAGTAGTCTGACCTC-1  17.78214
# UK-CIC10690373+UK-CIC10690565_AAGCCGCCATCGGACC-1 -44.82690
# UK-CIC10690377+UK-CIC10690569_AAAGCAACATGCAACT-1  15.59963
# UK-CIC10690377+UK-CIC10690569_AAAGCAATCAGCCTAA-1  13.17371
# UK-CIC10690377+UK-CIC10690569_AAAGTAGCAAACGTGG-1  17.78214
# UK-CIC10690381+UK-CIC10690573_AAACCTGTCCAAAGTC-1 -44.82690
# UK-CIC10690381+UK-CIC10690573_AAACGGGTCCGAAGAG-1  19.70217
# UK-CIC10690381+UK-CIC10690573_AACTCCCCAGCCAATT-1  17.63345

# %%
library(lmerTest)
library(BiocParallel)
# Out:
# Loading required package: lme4
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
options(warn = -1)
res <- as.list(1:nrow(nhoodCounts(mylo)))

# %%
res <- bplapply(res, function(x) glmer.nb(nhoodCounts(mylo)[x,] ~ case_control + sex + PC1_nonafricanVsAfrican + PC2_asianVsEuropean + age_scaled + (1|individual_id), offset = log(colSums(nhoodCounts(mylo))), data = metadata, control=glmerControl(check.conv.singular = .makeCC(action = "ignore",  tol = 1e-2), optimizer="bobyqa", tol=1e-02)), BPPARAM = MulticoreParam(workers = 23, progressbar = TRUE))
# Out:
#   |======================================================================| 100%

# %%
res_summary <- bplapply(res, summary, BPPARAM = MulticoreParam(workers = 23, progressbar = TRUE))
# Out:
#   |======================================================================| 100%

# %%
save(res_summary, res, metadata, file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_pos_vs_neg_milo_results_230622.RData')

# %%
load('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_pos_vs_neg_milo_results_230622.RData')

# %%
# example coefficients for 1 neighborhood
res_summary[[1]]$coefficients
# Out:
#                         Estimate     Std. Error z value      Pr(>|z|)
# (Intercept)             -9.501761757 0.69904482 -13.59249295 4.437057e-42
# case_controlPOSITIVE     0.037371255 0.40087604   0.09322397 9.257256e-01
# case_controlRECOVERY     0.136978940 0.53784324   0.25468191 7.989688e-01
# sexM                     0.723027047 0.34833947   2.07563914 3.792734e-02
# PC1_nonafricanVsAfrican  0.036225802 0.05677395   0.63807083 5.234276e-01
# PC2_asianVsEuropean      0.007484171 0.01009220   0.74158007 4.583418e-01
# age_scaled              -0.130802760 0.18240284  -0.71710925 4.733067e-01

# %%
singulars <- lapply(res, function(x) as.numeric(isSingular(x)))
conv <- lapply(res, function(x) length(slot(x, "optinfo")$conv$lme4$messages))

# %%
pvalue <- bplapply(res_summary, function(x) x$coefficients[2,4], BPPARAM = SerialParam(progress = TRUE))
# Out:
#   |======================================================================| 100%

# %%
beta <- bplapply(res_summary, function(x) x$coefficients[2,1], BPPARAM = SerialParam(progress = TRUE))
# Out:
#   |======================================================================| 100%

# %%
da.res = data.frame(Nhood = as.numeric(1:nrow(nhoodCounts(mylo))), beta = do.call(c, beta), PValue = do.call(c, pvalue))

# %%
da.res$Singular <- singulars
da.res$Conv <- conv

# %%
da.res$SpatialFDR <- graphSpatialFDR(x.nhoods=nhoods(mylo), graph=miloR::graph(mylo),
    weighting='k-distance', pvalues=da.res$PValue,
    indices=nhoodIndex(mylo), distances=nhoodDistances(mylo),
    reduced.dimensions=reducedDim(mylo, 'X_scVI'), k = 50)
da.res$Diff <- sign(da.res$beta)
da.res$Diff[da.res$SpatialFDR >= 0.1 | da.res$Conv > 0] <- 0
saveRDS(da.res, file = 'h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_pos_vs_neg_milo_results_DA_230622.RDS')

# %%
table(da.res$Diff)
# Out:
#   -1    0    1
#  327 6255    3

# %%
# da.res <- readRDS('h5ad/df.fil3_gex_bcells_no_CLL_vdj_trimmed_wave2_rec_vs_neg_milo_results_DA_230622.RDS')

# %%
library(ggbeeswarm)
library(ggplot2)
new_DA_beeswarm <- function (da.res1, da.res2 = NULL, max = 5, color.by = 'SpatialFDR', group.by = NULL, split.by =NULL, alpha = 0.1, subset.nhoods = NULL, size = 2, filter = c('Mixed', 'doublets')) {
    if (!is.null(da.res2) && !is.null(split.by)){
        da.res1$split = split.by[1]
        da.res2$split = split.by[2]
        da.res <- rbind(da.res1, da.res2)
    } else {
        da.res <- da.res1
    }

    da.res$beta[da.res$beta > max] <- max
    da.res$beta[da.res$beta < -max] <- -max
    da.res <- da.res %>% filter(!get(group.by) %in% filter)
    if (!is.null(group.by)) {
        if (!group.by %in% colnames(da.res)) {
            stop(paste0(group.by, " is not a column in da.res. Have you forgot to run annotateNhoods(x, da.res, ", 
                group.by, ")?"))
        }
        if (is.numeric(da.res[, group.by])) {
            stop(paste0(group.by, " is a numeric variable. Please bin to use for grouping."))
        }
        da.res <- mutate(da.res, group_by = da.res[, group.by])
    }else {
        da.res <- mutate(da.res, group_by = "g1")
    }    
    if (!is.factor(da.res[, "group_by"])) {
        message(paste0("Converting group.by to factor..."))
        da.res <- mutate(da.res, factor(group_by, levels = unique(group_by)))
    }
    if (!is.null(subset.nhoods)) {
        da.res <- da.res[subset.nhoods, ]
    }
    
    da.res <- da.res %>% mutate(is_signif = ifelse((get(color.by) < alpha & get('Singular') < 1 & get('Conv') < 1), 
        1, 0)) %>% mutate(beta_color = ifelse(is_signif == 1, 
        beta, NA)) %>% arrange(group_by) %>% mutate(Nhood = factor(Nhood, 
        levels = unique(Nhood)))
    if (!is.null(split.by)){
        p <- ggplot(da.res, aes(group_by, beta, color = beta_color)) + 
            scale_color_gradient2(midpoint = 0, low = "#0571b0", mid = '#f7f7f7', high = "#ca0020", limits=c(-max/3, max/3), oob=scales::squish) +
            guides(color = "none") + 
            xlab(group.by) + 
            ylab("beta") + 
            geom_quasirandom(alpha = 1, size = size) +
            coord_flip() + 
            theme_bw() + 
            theme(axis.title.y = element_blank(),
                  axis.title.x = element_text(size=20, color = '#000000'),
                  axis.text = element_text(size=20, color = '#000000'),
                  axis.ticks = element_line(color = '#000000'),
                  panel.border = element_rect(colour = "#000000")
                ) + 
            facet_wrap(split~.) +
            theme(strip.background = element_blank(), strip.text.x = element_text(angle = 0, size = 20, color = '#000000'))
    } else {
        p <- ggplot(da.res, aes(group_by, beta, color = beta_color)) + 
        scale_color_gradient2(midpoint = 0, low = "#0571b0", mid = '#f7f7f7', high = "#ca0020", limits=c(-max/3, max/3), oob=scales::squish) +
        guides(color = "none") + 
        xlab(group.by) + 
        ylab("beta") + 
        geom_quasirandom(alpha = 1, size = size) +
        coord_flip() + 
        theme_bw() + 
        theme(axis.title.y = element_blank(),
              axis.title.x = element_text(size=20, color = '#000000'),
              axis.text = element_text(size=20, color = '#000000'),
              axis.ticks = element_line(color = '#000000'),
              panel.border = element_rect(colour = "#000000")
            ) + 
        theme(strip.background = element_blank(), strip.text.x = element_text(angle = 0, size = 20, color = '#000000'))
    }
    
    p$data <- p$data[order(p$data$beta_color, na.last = FALSE), ]
    return(p)
}
# Out:
# Loading required package: ggplot2

# %%
# options(repr.plot.width=20, repr.plot.height=10)
da.res <- annotateNhoods(mylo, da.res, coldata_col = "celltype_B_corrected")
da.res$celltype_B_corrected <- ifelse(da.res$celltype_B_corrected_fraction < 0.7, "Mixed", da.res$celltype_B_corrected)
p <- new_DA_beeswarm(da.res, color.by = 'SpatialFDR', group.by = "celltype_B_corrected", size = 2, alpha = .05)
p
# Out:
# Converting group.by to factor...
# plot without title

# %%
# options(repr.plot.width=20, repr.plot.height=10)
da.res <- annotateNhoods(mylo, da.res, coldata_col = "celltype_B_corrected_IFN")
da.res$celltype_B_corrected_IFN <- ifelse(da.res$celltype_B_corrected_IFN_fraction < 0.7, "Mixed", da.res$celltype_B_corrected_IFN)
p <- new_DA_beeswarm(da.res, color.by = 'SpatialFDR', group.by = "celltype_B_corrected_IFN", size = 2, alpha = .05)
p
# Out:
# Converting group.by to factor...
# plot without title
