# %%
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(scran))
suppressPackageStartupMessages(library(scater))
suppressPackageStartupMessages(library(emmeans))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(ggpubr))
suppressPackageStartupMessages(library(lmerTest))
suppressPackageStartupMessages(library(msigdbr))
suppressPackageStartupMessages(library(dplyr))

# %%
setwd('/lustre/scratch117/cellgen/team297/kt16/COVID_imperial_renal/')
sce <- readRDS('h5ad/df.fil3_gex_bcells_vdj_sce_B_mem_all.RDS')
counts(sce) <- assays(sce)[['X']] # because i'm saving from a h5ad object with anndata2ri
sce$case_control <- factor(sce$case_control, levels = c('NEGATIVE', 'POSITIVE', 'RECOVERY'))
sce$WHO_temp_severity <- factor(sce$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'))
sce$WHO_temp_severity_group <- factor(sce$WHO_temp_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical'))
sce$WHO_severity_group <- factor(sce$WHO_severity, levels = c('NA', 'mild', 'moderate', 'severe', 'critical'), labels = c('NA', 'mild_moderate', 'mild_moderate', 'severe_critical', 'severe_critical')) # interpreted as peak severity
sce$grouped_temp_severity <- ifelse(sce$WHO_temp_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
sce$grouped_severity <- ifelse(sce$WHO_severity %in% c("mild", "moderate"), "mild_moderate", "severe_critical")
sce$age_scaled <- scale(sce$calc_age) # scale age
min_cells = 10
# remove samples >21 days
sce2 <- sce[,sce$time_from_infection <= 21] # prevent issues with spline
# Remove samples with less than 10 cells
nCells <- table(sce2$sample_id)
rmSamples <- names(nCells[nCells < min_cells])
sce2 <- sce2[, !sce2$sample_id %in% rmSamples]
# remove negatives and recoveries
sce3 <- sce2[,sce2$case_control == 'POSITIVE']
sce3
# Out:
# class: SingleCellExperiment
# dim: 32913 9279
# metadata(10): WHO_temp_severity_colors case_control_colors ...
#   initial_cluster_B_colors seurat_clusters_colors
# assays(2): X counts
# rownames(32913): MIR1302-2HG FAM138A ... AC213203.1 FAM231C
# rowData names(6): vst.mean vst.variance ... vst.variable GEX
# colnames(9279): UK-CIC10689738+UK-CIC10690026_AAGGTTCGTGCGCTTG-1
#   UK-CIC10689738+UK-CIC10690026_ACCTTTATCATGCAAC-1 ...
#   UK-CIC10690384+UK-CIC10690576_TTTACTGAGGTGGGTT-1
#   UK-CIC10690384+UK-CIC10690576_TTTATGCTCCTCAATT-1
# colData names(72): orig.ident nCount_RNA ... grouped_severity
#   age_scaled
# reducedDimNames(5): X_harmony_rna X_pca_rna UMAP X_umapafterharmony_rna
#   X_umapbeforeharmony_rna
# altExpNames(0):

# %%
# Summarize Counts
smrzd <- aggregateAcrossCells(sce3, id = as.character(colData(sce3)[, c("sample_id")]))
smrzd <- logNormCounts(smrzd)
smrzd
# Out:
# class: SingleCellExperiment
# dim: 32913 123
# metadata(10): WHO_temp_severity_colors case_control_colors ...
#   initial_cluster_B_colors seurat_clusters_colors
# assays(2): counts logcounts
# rownames(32913): MIR1302-2HG FAM138A ... AC213203.1 FAM231C
# rowData names(6): vst.mean vst.variance ... vst.variable GEX
# colnames(123): C101_110121 C101_130121 ... C93_2104 C93_2704
# colData names(75): orig.ident nCount_RNA ... ncells sizeFactor
# reducedDimNames(5): X_harmony_rna X_pca_rna UMAP X_umapafterharmony_rna
#   X_umapbeforeharmony_rna
# altExpNames(0):

# %%
length(table(droplevels(smrzd$individual_id)))
# Out:
# [1] 36

# %%
fullFormula = as.formula("geneset ~ splines::bs(time_from_infection, degree = 2) * grouped_severity + sex + ethnicity + age_scaled + centre + (1|individual_id)")
fullFormula
# Out:
# geneset ~ splines::bs(time_from_infection, degree = 2) * grouped_severity +
#     sex + ethnicity + age_scaled + centre + (1 | individual_id)

# %% [markdown]
# ### Run the spline model but on gene sets

# %% [markdown]
# ### Hallmark

# %%
m <- msigdbr(category = 'H')
genelists <- split(m, m$gs_name)
genelists <- lapply(genelists, function(x) x %>% select(gene_symbol) %>% unlist %>% as.character)

# %%
seu <- as.Seurat(smrzd)
data <- seu@meta.data
seu <- AddModuleScore(seu, features = genelists, name = names(genelists))
# Out:
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_harmony_rna_ to Xharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xharmonyrna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_pca_rna_ to Xpcarna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xpcarna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_umapafterharmony_rna_ to Xumapafterharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xumapafterharmonyrna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_umapbeforeharmony_rna_ to Xumapbeforeharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xumapbeforeharmonyrna_”
# Warning message:
# “The following features are not present in the object: MTARC2, SLC66A3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AARS1, DARS1, RARS1, WARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, H1-0, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NIBAN1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: POLR1H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2AZ1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN1, CCN2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN5, PLAAT3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN5, GFUS, PLAAT3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AZ1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2AZ1, H2AZ2, H2BC12, PTTG3P, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GFUS, RARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CROCCP2, H1-0, H4C3, HBBP1, MARCHF2, MARCHF8, SLC66A2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN1, CCN2, CCN5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: WARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MARCHF1, WARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MACROH2A2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2BC3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SEPTIN9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: EPRS1, NIBAN1, WARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: EPRS1, H2AZ1, IARS1, KARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DENND2B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-2, H2AJ, H2AW, IRAG2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DOP1A, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-6, SEPTIN4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, IARS1, TARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN1, DMAC2L, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, TARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GSTT2, KARS1, MARCHF6, not searching for symbol synonyms”

# %%
fits <- lapply(paste0(names(genelists), 1:length(genelists)), function(x){
    data$geneset <- seu@meta.data[,x]
    fit <- lmerTest::lmer(fullFormula, data = data)
    return(list(fit=fit, data=data))
})
# Out:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular

# %%
fit_res <- lapply(fits, function(x) anova(x$fit))
singular <- lapply(fits, function(x) as.numeric(isSingular(x$fit)))
conv <- lapply(fits, function(x) length(slot(x$fit, "optinfo")$conv$lme4$messages))
pvals <- lapply(fit_res, function(x) x[7,6])
qvals <- p.adjust(pvals, method = 'BH')
df = data.frame(pvals = unlist(pvals), 
                qvals = unlist(qvals), 
                singular = unlist(singular), 
                conv = unlist(conv), 
                row.names = paste0(names(genelists), 1:length(genelists)))
df = df[df$qval < 0.05 & df$singular == 0 & df$conv == 0,]
df
# Out:
#                                      pvals        qvals        singular conv
# HALLMARK_INTERFERON_ALPHA_RESPONSE26 8.378547e-05 0.0020946368 0        0
# HALLMARK_INTERFERON_GAMMA_RESPONSE27 7.440409e-06 0.0003720205 0        0

# %%
i = 26
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in log(geneset):
# “NaNs produced”
# Warning message in log(geneset):
# “NaNs produced”
# Warning message in log(geneset):
# “NaNs produced”
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# Warning message:
# “Removed 1 row(s) containing missing values (geom_path).”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %%
i = 27
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %% [markdown]
# ### KEGG

# %%
m <- msigdbr(category = 'C2', subcategory = 'CP:KEGG')
genelists <- split(m, m$gs_name)
genelists <- lapply(genelists, function(x) x %>% select(gene_symbol) %>% unlist %>% as.character)

# %%
seu <- as.Seurat(smrzd)
data <- seu@meta.data
seu <- AddModuleScore(seu, features = genelists, name = names(genelists))
# Out:
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_harmony_rna_ to Xharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xharmonyrna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_pca_rna_ to Xpcarna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xpcarna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_umapafterharmony_rna_ to Xumapafterharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xumapafterharmonyrna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_umapbeforeharmony_rna_ to Xumapbeforeharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xumapbeforeharmonyrna_”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ADSS1, ADSS2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ATP5MC1P5, COX6CP3, UQCR10P1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AARS1, CARS1, DARS1, EPRS1, GARS1, HARS1, IARS1, KARS1, LARS1, MARS1, NARS1, QARS1, RARS1, SARS1, TARS1, TARS3, VARS1, WARS1, YARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCSK, GFUS, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, KIR2DL2, KIR2DL5A, KIR2DS1, KIR2DS3, KIR2DS4, KIR2DS5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HMGB1P1, HMGB1P40, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: VDAC2P5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: COX6CP3, UQCR10P1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SKP1P2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, PPBPP1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SUCLG2P2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, PPBPP1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: STING1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GSTT1, GSTT2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCGR2C, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCSK, GFUS, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB7P, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, GSTT1, GSTT2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PNLIPRP2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, KIR2DL2, KIR2DL5A, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ATP5MC1P5, COX6CP3, GPX1, UQCR10P1, VDAC2P5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCGR2C, HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GSTT1, GSTT2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: KIR2DL2, KIR2DL5A, KIR2DS1, KIR2DS3, KIR2DS4, KIR2DS5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: OR1D4, OR4C45, OR8G2P, OR8U3, OR8U8, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SKP1P2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ATP5MC1P5, COX6CP3, UQCR10P1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ATP5MC1P5, COX6CP3, SEPTIN5, UQCR10P1, VDAC2P5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB7P, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: EPRS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MMUT, SUCLG2P2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PSMA6P4, PSMC1P4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SRP9P1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ADSS1, ADSS2, POLR1H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: POLR1H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TMSB4XP8, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ACP3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: RSL24D1P11, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: STING1, TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: C1DP2, C1DP3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: POLR1H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HNRNPA1P60, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GBA3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCGR2C, H2AB1, H2AB2, H2AB3, H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2ACP1, H2AJ, H2AW, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H2BW1, H2BW2, H3-3A, H3-3B, H3-4, H3-5, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H3Y1, H3Y2, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C7, H4C8, H4C9, HLA-DRB3, HLA-DRB4, MACROH2A1, MACROH2A2, RO60, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TAS2R45, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SKP1P2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: WARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SKP1P2, UBE2NL, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IARS1, LARS1, VARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MMUT, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IRAG1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SKP1P2, not searching for symbol synonyms”

# %%
fits <- lapply(paste0(names(genelists), 1:length(genelists)), function(x){
    data$geneset <- seu@meta.data[,x]
    fit <- lmerTest::lmer(fullFormula, data = data)
    return(list(fit=fit, data=data))
})
# Out:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular

# %%
fit_res <- lapply(fits, function(x) anova(x$fit))
singular <- lapply(fits, function(x) as.numeric(isSingular(x$fit)))
conv <- lapply(fits, function(x) length(slot(x$fit, "optinfo")$conv$lme4$messages))
pvals <- lapply(fit_res, function(x) x[7,6])
qvals <- p.adjust(pvals, method = 'BH')
df = data.frame(pvals = unlist(pvals), 
                qvals = unlist(qvals), 
                singular = unlist(singular), 
                conv = unlist(conv), 
                row.names = paste0(names(genelists), 1:length(genelists)))
df = df[df$qval < 0.05 & df$singular == 0 & df$conv == 0,]
df
# Out:
#                                            pvals        qvals       singular
# KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION13 5.595131e-05 0.005203472 0
# KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY42       2.260455e-05 0.004204447 0
# KEGG_GRAFT_VERSUS_HOST_DISEASE78           7.341985e-04 0.045520306 0
#                                            conv
# KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION13 0
# KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY42       0
# KEGG_GRAFT_VERSUS_HOST_DISEASE78           0

# %%
i = 13
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %%
i = 42
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in log(geneset):
# “NaNs produced”
# Warning message in log(geneset):
# “NaNs produced”
# Warning message in log(geneset):
# “NaNs produced”
# Warning message:
# “Removed 50 rows containing missing values (geom_point).”
# Warning message:
# “Removed 47 row(s) containing missing values (geom_path).”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %%
i = 78
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %% [markdown]
# ### REACTOME

# %%
m <- msigdbr(category = 'C2', subcategory = 'CP:REACTOME')
genelists <- split(m, m$gs_name)
genelists <- lapply(genelists, function(x) x %>% select(gene_symbol) %>% unlist %>% as.character)

# %%
seu <- as.Seurat(smrzd)
data <- seu@meta.data
seu <- AddModuleScore(seu, features = genelists, name = names(genelists))
# Out:
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_harmony_rna_ to Xharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xharmonyrna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_pca_rna_ to Xpcarna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xpcarna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_umapafterharmony_rna_ to Xumapafterharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xumapafterharmonyrna_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from X_umapbeforeharmony_rna_ to Xumapbeforeharmonyrna_”
# Warning message:
# “All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to Xumapbeforeharmonyrna_”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: C4B_2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PLAAT3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PLAAT1, PLAAT2, PLAAT3, PLAAT4, PLAAT5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PLAAT3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PLAAT3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, IGHD, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, KIR2DL2, KIR2DS1, KIR2DS2, LILRA3, TRAV19, TRAV29DV5, TRAV8-4, TRBV12-3, TRBV7-9, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AKR7L, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AX, H2AZ1, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, SEPTIN2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHD, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, SEPTIN4, TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SEPTIN4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, PRXL2B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PDCD6-AHRR, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCSK, GFUS, MARCHF6, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ADPRS, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AKR7L, BPNT2, GSTT1, GSTT2, MTARC1, MTARC2, PDCD6-AHRR, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCSK, GFUS, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, POLR1F, POLR1G, POLR1H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MARCHF6, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHD, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MIR24-1, MIR24-2, NUP42, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MIR24-1, MIR24-2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IRAG1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AW, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, ZZZ3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, DYNC2I1, DYNC2I2, DYNLT2, DYNLT2B, SEPTIN2, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CBLIF, MMUT, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: C4B_2, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, TRAV19, TRAV29DV5, TRAV8-4, TRBV12-3, TRBV7-9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DMAC2L, MICOS10, MICOS13, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PDCD6-AHRR, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, HLA-DRB3, HLA-DRB4, HLA-H, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CIAO2B, CIAO3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: STING1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: BPNT2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AARS1, CARS1, DARS1, EPRS1, GARS1, HARS1, IARS1, KARS1, LARS1, MARS1, NARS1, QARS1, RARS1, SARS1, TARS1, VARS1, WARS1, YARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: KIR2DS1, KIR2DS2, KIR2DS3, KIR2DS4, KIR2DS5, KIR3DS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CBLIF, MMUT, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CBLIF, MMUT, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TLE5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, LORICRIN, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PNLIPRP2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PNLIPRP2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PNLIPRP2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SSPOP, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SSPOP, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CBLIF, MMUT, SSPOP, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ADPRS, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PDCD6-AHRR, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, POLR1F, POLR1G, POLR1H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MARCHF6, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, MMUT, PRXL2B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DMAC2L, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H1-0, H1-1, H1-2, H1-3, H1-4, H1-5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: LORICRIN, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ARSL, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCSK, GFUS, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, TRAV19, TRAV29DV5, TRAV8-4, TRBV12-3, TRBV7-9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MIR23B, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GSTT1, GSTT2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PLAAT1, PLAAT2, PLAAT3, PLAAT4, PLAAT5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ARSL, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, ZZZ3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CYRIB, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, IRAG1, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AX, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, KIR2DL2, KIR2DS1, KIR2DS2, LILRA3, TRAV19, TRAV29DV5, TRAV8-4, TRBV12-3, TRBV7-9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, NUP42, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: C4B_2, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ACP3, C4B_2, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, IRAG2, KIR2DS1, KIR2DS2, KIR2DS3, KIR2DS4, KIR2DS5, KIR3DS1, LILRA3, STING1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GET1, GET3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, HLA-H, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, HLA-H, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DYNC2I1, DYNC2I2, DYNLT2, DYNLT2B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SEPTIN4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: STING1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: LORICRIN, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MIR34B, MIR34C, SEPTIN7, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MIR34B, MIR34C, SEPTIN7, not searching for symbol synonyms”
# Warning message:
# ...
# Warning message:
# “The following features are not present in the object: CCN2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DARS1, EPRS1, IARS1, KARS1, LARS1, MARS1, QARS1, RARS1, SARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: OR2T7, OR4Q2, OR51H1, OR51J1, OR52Z1, OR8U3, OR8U9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CEP43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCL3L3, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MIR150, MIR181C, MIR200B, MIR200C, MIR206, MIR302A, MIR34B, MIR34C, MIR449A, MIR449B, MIR449C, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GARRE1, H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MRTFA, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: IGHD, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, TLE5, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SEPTIN4, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CERT1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ARSL, CERT1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: STING1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MRTFA, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MRTFA, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: GPX1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PRXL2B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: FCSK, GFUS, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: HLA-DRB3, HLA-DRB4, TRAV19, TRAV29DV5, TRAV8-4, TRBV12-3, TRBV7-9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3-4, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: ARSL, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DMAC2L, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TRADD, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MIR132, MIR137, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, MIR27A, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MIR24-1, MIR24-2, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AB1, H2AC14, H2AC18, H2AC19, H2AC20, H2AC4, H2AC6, H2AC7, H2AC8, H2AJ, H2AX, H2AZ1, H2AZ2, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BS1, H2BU1, H3-3A, H3-3B, H3C1, H3C10, H3C11, H3C12, H3C13, H3C14, H3C15, H3C2, H3C3, H3C4, H3C6, H3C7, H3C8, H4-16, H4C1, H4C11, H4C12, H4C13, H4C14, H4C15, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AARS1, CARS1, DARS1, EPRS1, GARS1, HARS1, IARS1, KARS1, LARS1, MARS1, MT-RNR1, MT-RNR2, NARS1, QARS1, RARS1, SARS1, TARS1, VARS1, WARS1, YARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: SLC66A1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: AARS1, CARS1, DARS1, EPRS1, GARS1, HARS1, IARS1, KARS1, LARS1, MARS1, NARS1, QARS1, RARS1, SARS1, TARS1, VARS1, WARS1, YARS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PRORP, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: EPRS1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: EPRS1, MT-RNR1, MT-RNR2, NUP42, PRORP, RPPH1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: MT-RNR1, MT-RNR2, PRORP, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, RPPH1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, H2BC1, H2BC10, H2BC11, H2BC12, H2BC13, H2BC14, H2BC15, H2BC17, H2BC18, H2BC21, H2BC3, H2BC4, H2BC5, H2BC6, H2BC7, H2BC8, H2BC9, H2BU1, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: H2AC1, H2AC11, H2AC12, H2AC13, H2AC14, H2AC15, H2AC16, H2AC17, H2AC18, H2AC19, H2AC20, H2AC21, H2AC4, H2AC6, H2AC7, H2AC8, H2AW, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: DENND2B, IGHV1-2, IGHV1-46, IGHV1-69, IGHV2-5, IGHV2-70, IGHV3-11, IGHV3-13, IGHV3-23, IGHV3-30, IGHV3-33, IGHV3-48, IGHV3-53, IGHV3-7, IGHV4-34, IGHV4-39, IGHV4-59, IGKV1-12, IGKV1-16, IGKV1-17, IGKV1-33, IGKV1-39, IGKV1-5, IGKV1D-12, IGKV1D-16, IGKV1D-33, IGKV1D-39, IGKV2-28, IGKV2-30, IGKV2D-28, IGKV2D-30, IGKV2D-40, IGKV3-11, IGKV3-15, IGKV3-20, IGKV3D-20, IGKV4-1, IGKV5-2, IGLC2, IGLC3, IGLV1-40, IGLV1-44, IGLV1-47, IGLV1-51, IGLV2-11, IGLV2-14, IGLV2-23, IGLV2-8, IGLV3-1, IGLV3-19, IGLV3-21, IGLV3-25, IGLV3-27, IGLV6-57, IGLV7-43, TUBB8B, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: NUP42, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: PDCD6-AHRR, not searching for symbol synonyms”
# Warning message:
# “The following features are not present in the object: CCN2, not searching for symbol synonyms”

# %%
fits <- lapply(paste0(names(genelists), 1:length(genelists)), function(x){
    data$geneset <- seu@meta.data[,x]
    fit <- lmerTest::lmer(fullFormula, data = data)
    return(list(fit=fit, data=data))
})
# Out:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular

# %%
fit_res <- lapply(fits, function(x) anova(x$fit))
singular <- lapply(fits, function(x) as.numeric(isSingular(x$fit)))
conv <- lapply(fits, function(x) length(slot(x$fit, "optinfo")$conv$lme4$messages))
pvals <- lapply(fit_res, function(x) x[7,6])
qvals <- p.adjust(pvals, method = 'BH')
df = data.frame(pvals = unlist(pvals), 
                qvals = unlist(qvals), 
                singular = unlist(singular), 
                conv = unlist(conv), 
                row.names = paste0(names(genelists), 1:length(genelists)))
df = df[df$qval < 0.05 & df$singular == 0 & df$conv == 0,]
df
# Out:
#                                             pvals        qvals       singular
# REACTOME_INTERFERON_ALPHA_BETA_SIGNALING642 4.574735e-06 0.007337875 0
# REACTOME_INTERFERON_GAMMA_SIGNALING643      5.255926e-05 0.037840706 0
# REACTOME_INTERFERON_SIGNALING644            7.077439e-05 0.037840706 0
#                                             conv
# REACTOME_INTERFERON_ALPHA_BETA_SIGNALING642 0
# REACTOME_INTERFERON_GAMMA_SIGNALING643      0
# REACTOME_INTERFERON_SIGNALING644            0

# %%
i = 642
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %%
i = 643
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title

# %%
i = 644
x = emmeans(fits[[i]]$fit, ~ time_from_infection | grouped_severity, at = list(time_from_infection = 0:21))
theme_set(theme_pubr())

ggplot(data.frame(x), aes(time_from_infection, emmean, group = grouped_severity, fill = grouped_severity)) +
    geom_line(aes(colour = grouped_severity), size = 1.7) +
    geom_ribbon(aes(ymin = lower.CL, ymax = upper.CL), alpha = 0.055) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    scale_fill_manual(values = c("#2C7BB6", "#D7191C"))

ggplot(fits[[i]]$data, aes(time_from_infection, geneset, col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())

ggplot(fits[[i]]$data, aes(time_from_infection, log(geneset), col = grouped_severity)) +
    geom_point(alpha = 0.7, size = 0.7) +
    geom_line(aes(group = individual_id), alpha = 0.7, size = 0.8) +
    scale_color_manual(values = c("#2C7BB6", "#D7191C")) +
    facet_wrap(~grouped_severity) +
    theme(strip.background = element_blank(), strip.text.x = element_blank(), strip.text.y = element_blank())
# Out:
# Warning message in splines::bs(time_from_infection, degree = 2L, knots = numeric(0), :
# “some 'x' values beyond boundary knots may cause ill-conditioned bases”
# Warning message in grid.Call.graphics(C_polygon, x$x, x$y, index):
# “semi-transparency is not supported on this device: reported only once per page”
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# Warning message in grid.Call.graphics(C_points, x$x, x$y, x$pch, x$size):
# “semi-transparency is not supported on this device: reported only once per page”
# plot without title
# plot without title
