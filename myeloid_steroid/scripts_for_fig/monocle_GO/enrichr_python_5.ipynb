# %%
import pandas as pd
import gseapy as gp
import matplotlib.pyplot as plt
import scanpy as sc
import glob
from gseapy.plot import barplot, dotplot

# %%
newlist2 =['FTH1','ACTB','EEF1B2','VIM','PFN1','NACA','EEF1A1','TPT1','FAU','TMSB4X','MTRNR2L12','OAZ1','S100A6','S100A8','SH3BGRL3','GAPDH','S100A9','S100A4','S100A12','NEAT1']

# %%
newlist2=['ZFC3H1',
 'PREX1',
 'DAZAP2',
 'OGFRL1',
 'RNF130',
 'UBB',
 'ANKRD12',
 'CHD4',
 'FKBP5',
 'PEA15',
 'CDC42SE1',
 'IGFBP2',
 'YWHAZ',
 'RPL8',
 'IFI44',
 'GSTM1',
 'RAD23B',
 'CD302',
 'FHL3',
 'PTP4A2',
 'BHLHE40',
 'MYADM',
 'PTPN18',
 'SPECC1',
 'TMEM176A',
 'CALCOCO2',
 'IER3',
 'ARF6',
 'MAPK1IP1L',
 'FBXL5',
 'FES',
 'GSTP1',
 'SNX29',
 'IQGAP1',
 'NSA2',
 'PHF20',
 'KLHDC7B',
 'DMXL2',
 'NFKB2',
 'TET2',
 'OGT',
 'HNRNPDL',
 'SERTAD2',
 'RGS10',
 'CARHSP1',
 'SLC1A3',
 'LILRB3',
 'RPL37',
 'USP3',
 'MDM2',
 'PRKX',
 'RPL10',
 'MAP2K1',
 'RAP1B',
 'RELB',
 'TUBB',
 'KLF3',
 'PILRA',
 'SESN1',
 'CRISPLD2',
 'NCF1',
 'NBPF10',
 'RNF144B',
 'ARRB2',
 'MBNL1',
 'ACAP2',
 'SNX2',
 'CCNI',
 'MT1X',
 'LY86',
 'DDX17',
 'HNRNPA1',
 'CALR',
 'MYO9B',
 'TTC7A',
 'SLC25A25',
 'WIPF1',
 'TMEM14C',
 'RIN3',
 'REL',
 'CREG1',
 'XAF1',
 'TOMM20',
 'NOTCH2',
 'RAP1A',
 'OAS3',
 'ADAM8',
 'JUP',
 'HLA-E',
 'IFI44L',
 'MT-ND6',
 'KIAA1551',
 'RAB13',
 'JAML',
 'IFITM3',
 'STAT6',
 'PLXNB2',
 'PTBP3',
 'CPPED1',
 'MT-ND4',
 'CRTAP',
 'CSGALNACT2',
 'CHMP4B',
 'EIF1',
 'VCAN',
 'HACD4',
 'HSP90AB1',
 'SPEN',
 'MT-ND4L',
 'ETS2',
 'CAST',
 'CLEC12A',
 'RNF213',
 'CLEC4E',
 'MAN2B1',
 'NLRP3',
 'UBE2D3',
 'GPSM3',
 'SFPQ',
 'ITGA4',
 'BEST1',
 'EVI2B',
 'FOXO3',
 'MSN',
 'TOM1',
 'PNISR',
 'ERP29',
 'RNH1',
 'SMC1A',
 'FCGR2A',
 'HNRNPK',
 'GDI2',
 'BTG1',
 'FAM118A',
 'EIF1AX',
 'SNHG7',
 'VIM-AS1',
 'HLA-DRB1',
 'CNPY3',
 'ABTB1',
 'KLF9',
 'RPL11',
 'SF3B1',
 'MYH9',
 'ALOX5',
 'CYBB',
 'IL1R2',
 'ZFAS1',
 'TGFB1',
 'AL133415.1',
 'BTF3',
 'HLA-F',
 'ADGRE5',
 'IFNGR1',
 'GSTK1',
 'KLF2',
 'FGL2',
 'CSF1R',
 'MAFB',
 'CD68',
 'IRF2BP2',
 'RPS27',
 'STK17B',
 'UBALD2',
 'NCOA4',
 'PIM3',
 'IFI6',
 'CD300E',
 'RHOB',
 'SEPT9',
 'PTMA',
 'CORO1C',
 'PCBP2',
 'YPEL3',
 'GPX4',
 'CALM2',
 'EPSTI1',
 'DDX3X',
 'GLRX',
 'CD44',
 'AL138963.3',
 'VIM',
 'SPTLC2',
 'RPL30',
 'GRN',
 'AHR',
 'TPT1',
 'HIST1H1E',
 'CYP27A1',
 'RSL1D1',
 'TMEM123',
 'KLF4',
 'CITED4',
 'NPM1',
 'LIMD2',
 'BLVRB',
 'SUMO2',
 'CTSS',
 'EIF2S3',
 'FOS',
 'RNASE6',
 'TYROBP',
 'MARCKS',
 'SDCBP',
 'SIGLEC1',
 'IER5',
 'PELI1',
 'NBPF19',
 'LAPTM5',
 'RPS18',
 'CSF3R',
 'CAPN2',
 'FN1',
 'PPT1',
 'BNIP3L',
 'GSN',
 'SRRM2',
 'FCN1',
 'MBOAT7',
 'RPS12',
 'RACK1',
 'PPP1R15A',
 'PLXDC2',
 'GLIPR1',
 'RPL10A',
 'CD4',
 'MGAT1',
 'FYB1',
 'RPL12',
 'LRP1',
 'MCL1',
 'HLA-A',
 'MT-ND5',
 'TAGLN2',
 'CD14',
 'DPYD',
 'CTSH',
 'RPS15A',
 'CXCR4',
 'LGALS9',
 'ODF3B',
 'H1FX',
 'DUSP1',
 'ZEB2',
 'LYZ',
 'TGFBI',
 'SMAP2',
 'ITM2B',
 'ZNF385A',
 'RPL14',
 'KLF10',
 'HNRNPU',
 'RPL29',
 'EEF2',
 'DDX5',
 'JUNB',
 'F13A1',
 'SQSTM1',
 'USP15',
 'LGALS3',
 'PSAP',
 'KLF6',
 'MTSS1',
 'B2M',
 'RNASE1',
 'CD37',
 'NACA',
 'CNBP',
 'TNFAIP3',
 'ANXA1',
 'ARL4A',
 'PNRC1',
 'ZFP36L2',
 'AP1S2',
 'RPL26',
 'CD74',
 'PLD3',
 'SAP30',
 'PCBP1',
 'ADA2',
 'PER1',
 'HLA-DQB1',
 'UBC',
 'DDIT4',
 'LMNA',
 'ZFP36L1',
 'ZFP36',
 'EEF1A1',
 'NEAT1',
 'MALAT1',
 'MTRNR2L12',
 'FTH1',
 'AHNAK',
 'SULT1A1',
 'CFD',
 'TSC22D3',
 'TXNIP',
 'RPS4X',
 'NFKBIA',
 'XIST']

# %%
newlist2 =['HBD','ALAS2','AHSP','HBB','HBM','HBA1','HBA2']

# %%
newlist2 =['HLA-DRB1','HLA-DRA','TYROBP','CD74','HLA-DPA1','HLA-DRB1','FTL','CST3','MARCKS','MALAT1','PLAC8','ISG15','IFITM1','APOBEC3A','MX1','IFI6',
          'IFITM3','LY6E','IFI44L','RSAD2','ISG20','IFIT3','SERPING1','IFIT1','IFIT2','TNFSF10','B2M','IFI27','TMSB10']

# %%
#newlist2 =['PTTG1','CDC25A','STMN1','CEP55','GINS2','SLC4A1','CENPF','TROAP','MK167','BIRC5','ALAS2',
         # 'HBD','AHSP','HBM','HBB','HBA1','HBA2']

# %%
#newlist2 =['HLA-DMA','DUSP6','PSAP','JUNB','CTSS','ZFP36','GNG5','HSPA8','CLIC1','HLA-DQB1','FTH1',
          #'ATP6V0C','CPVL','NPC2','PRELID1','PCBP1','BLVRB','OAZ1','ZFP36L1','SUMO2','LYZ','CNBP']

# %%
#newlist2 =['CSTB','TMSB4X','MTRNR2L12','ACTB','COTL1','ARPC3','LGALS3','FIF1','FAU','ATP4MC3','PFDN5',
         # 'BTF3','NACA','CHCHD2','UBA52','TSPO','H3F3A','TKT','PFN1','ARPC2','YBX1','GABARAP','AP1S2',
         # 'TPI1','RHOA','LGALS1','S100A6','FN1','S100A8','S100A4','CFL1','MYL6','CALM2','S100A9','SLC25A6',
         # 'ATP5MG','ACTG1','S100A10','LMNA','NEAT1','PPIA','VCAN','TALDO1','ALDOA','TPT1','ATP5MC2','GSTP1',
         # 'EIF3K','EIF3F','EEF2','EEF1A1','COX4I1','RACK1','EEF1B2','VIM','GAPDH','PABPC1','SLC25A5','SH3BGRL3',
        #  'AHNAK','ATP5F1E']

# %%
#newlist2 =['BLVRA','MX1','CMPK2','OASL','EPSTI1','ISG15','IFITM1','APOBEC3A','LAP3','PSMB9',
         # 'HERC5','IRF7','PLAC8','VAMP5','OAS1','OAS2','XAF1','MX2','LGALS3BP','OAS3','IFI35','MT2A',
         # 'SIGLEC1','LY6E','IFI44L','BST2','IFI6','IFITM3','IFITM2','TMSB10','IFI27','ABI3','MYL12A',
         ## 'KLF2','FCGR3A','GIMAP4','C1orf162','S100A11','HES4','PLSCR1','PARP14','IFIT2','IFIH1','RNF213',
         #  'GBP1','DRAP1','UBE2L6','HLA-A','IFIT3','SAMD9L','ISG20','RSAD2','TRIM22','SAMD9','TNFSF10','NT5C3A',
         #  'IFIT2','SERPING1','STAT1','TNFSF13B','PSME2','B2M','SELL','WARS','HLA-B','CD300E','MARCKS']

# %%
#newlist2 =['ZEB2','SERF2','HLA-DRA','CD37','HLA-DPB1','PILRA','TUBA1B','IER5','PSME1','TYROBP','NINJ1','HLA-DPA1','HLA-DRB1',
          #'ITM2B','CD74','CD48','LGALS2','FCER1G','CYBA','CD68','MYL12B','AIF1','SRGN','SERPINA1','CDKN1A','FTL','CFD',
         # 'HLA-DRB5','HLA-C','FGL2','LILRB1','MALAT1','NCF1','CST3']

# %%
# run enrichr
# if you are only intrested in dataframe that enrichr returned, please set no_plot=True

# list, dataframe, series inputs are supported
enr_go = gp.enrichr(gene_list=newlist2,
                 gene_sets=['GO_Biological_Process_2021'],
                 organism='Human', # don't forget to set organism to the one you desired! e.g. Yeast
                 #background='hsapiens_gene_ensembl',
                 description='test_name',
                 outdir='gsea_output/',
                 no_plot=True,
                 cutoff=0.5 # test dataset, use lower value from range(0,1)
                )

enr_kegg = gp.enrichr(gene_list=newlist2,
                 gene_sets=['KEGG_2021_Human'],
                 organism='Human', # don't forget to set organism to the one you desired! e.g. Yeast
                 #background='hsapiens_gene_ensembl',
                 description='test_name',
                 outdir='gsea_output/',
                 no_plot=True,
                 cutoff=0.5 # test dataset, use lower value from range(0,1)
                )

enr_hm = gp.enrichr(gene_list=newlist2,
                 gene_sets=['MSigDB_Hallmark_2020'],
                 organism='Human', # don't forget to set organism to the one you desired! e.g. Yeast
                 #background='hsapiens_gene_ensembl',
                 description='test_name',
                 outdir='gsea_output/',
                 no_plot=True,
                 cutoff=0.5 # test dataset, use lower value from range(0,1)
                )

# %%
# to save your figure, make sure that ``ofname`` is not None
gp.dotplot(enr_kegg.res2d, title='KEGG_2021_Human',cmap='viridis_r', top_term=25)#ofname='/home/jovyan/scripts/renal_covid_19/milo/gsea_output/before_allCD14_kegg.png'

# %%
gp.dotplot(enr_hm.res2d, title='MSigDB_Hallmark_2020',cmap='viridis_r', top_term=25)#,ofname='/home/jovyan/scripts/renal_covid_19/milo/gsea_output/all_anti_hm.png'

# %%
import numpy as np
gp.dotplot(enr_go.res2d, title='GO_Biological_Process_2021',cmap='viridis_r',
          ofname='/home/jovyan/scripts/renal_covid_19/steroid_pipeline_corrected/steroid_pipeline/trajectory_with_Rik_model_output/GO_pathway_before_steroid.pdf',
          dpi=300)#, top_term=25,ofname='/home/jovyan/scripts/renal_covid_19/milo/gsea_output/all_anti_go.png'

# %%
enr_go.res2d = enr_go.res2d.loc[enr_go.res2d['Adjusted P-value']<=0.05]
enr_kegg.res2d = enr_kegg.res2d.loc[enr_kegg.res2d['Adjusted P-value']<=0.05]
enr_hm.res2d = enr_hm.res2d.loc[enr_hm.res2d['Adjusted P-value']<=0.05]

# %%
enr_go.res2d.to_csv('/home/jovyan/scripts/renal_covid_19/milo/gsea_output/after_DC3_IFN_go.csv',index=False)
enr_kegg.res2d.to_csv('/home/jovyan/scripts/renal_covid_19/milo/gsea_output/after_DC3_IFN_kegg.csv',index=False)
enr_hm.res2d.to_csv('/home/jovyan/scripts/renal_covid_19/milo/gsea_output/after_DC3_IFN_hm.csv',index=False)

# %%
enr_go.res2d[0:20]
